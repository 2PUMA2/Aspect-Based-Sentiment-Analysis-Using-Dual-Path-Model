# %%
import openai
import json
import random
from typing import List, Tuple, Dict
import time
from collections import Counter
import re

class DirectEntityNERGenerator:
    def __init__(self, api_key: str, model: str = "gpt-4"):
        """
        직접 엔티티 형식으로 NER 데이터를 생성하는 클래스
        
        Args:
            api_key: OpenAI API 키
            model: 사용할 GPT 모델명
        """
        self.client = openai.OpenAI(api_key=api_key)
        self.model = model
        self.results = []
        
    def create_direct_entity_prompt(self) -> str:
        """직접 엔티티 형식으로 생성하는 프롬프트"""
        
        prompt = '''당신은 한국어 제품 리뷰에서 감정과 속성을 추출하는 NER 데이터 생성 전문가입니다.

## 🎯 **데이터 증강 우선순위 (현재 부족한 클래스 집중)**

**증강 대상:**
- 브랜드#가격
- 브랜드#다양성
- 브랜드#디자인
- 브랜드#인지도
- 브랜드#편의성
- 패키지/구성품#가격
- 패키지/구성품#다양성
- 패키지/구성품#디자인
- 패키지/구성품#인지도
- 패키지/구성품#편의성

## 📋 **엔티티 유형과 속성**

**엔티티 유형:**
- **브랜드**: 모든 분야의 제조사/브랜드 (전자, 패션, 화장품, 식품, 자동차, 가구 등 제한 없음)
- **패키지/구성품**: 포장재, 액세서리, 부속품, 사은품 등

**속성:**
- **가격**: 비용, 가성비, 할인, 경제성
- **다양성**: 선택의 폭, 옵션, 변형, 종류
- **인지도**: 유명함, 인기, 브랜드 파워, 화제성
- **편의성**: 사용 편리함, 접근성, 사용성
- **디자인**: 외관, 색상, 스타일, 미적 요소, 시각적 매력

## **생성 전략**

1. **다양한 분야의 브랜드, 패키지/구성품 활용**: 전자제품뿐만 아니라 화장품, 패션, 식품, 자동차, 가구, 문구, 완구, 스포츠용품 등 모든 분야
2. **실제 존재하는 브랜드명, 패키지/구성품명 사용**: 국내외 유명 브랜드들을 제한 없이 활용, 패키지/구성품도 제한 없이 활용
3. **다양한 스타일**: 리뷰, 설명, SNS 포스팅 등 다양한 스타일로 문장 생성

## **중요 규칙**

1. **실제 브랜드명 및 패키지/구성품 명 사용** - 추상적 표현 금지
2. **조사/어미 제외** - 핵심 명사/명사구만 추출
3. **다양한 분야 포괄** - 특정 카테고리에 국한되지 않음
4. **높은 다양성** - 최대한 다양한 브랜드/구성품 활용, 실제 있는 중소기업들 혹은 그들의 물품도 활용
5. **positive/neutral/negative의 적절한 분배** - 각 속성마다 positive/neutral/negative 문장의 수가 **각각 0.5:2:2 비율**로 나올 수 있도록 설정

## **출력 형식**

문장: [생성된 리뷰 문장]
엔티티: [["엔티티타입#속성", [["단어", 시작위치, 끝위치], ...], "감정"], ...]

**참고사항**: 
- 감정: "positive", "negative", "neutral" 중 선택
- 엔티티에 해당하는 명확한 단어가 없으면 [None, 0, 0] 사용
- 시작위치와 끝위치는 문자 단위 인덱스 (0부터 시작)

## **기존 데이터 예시 (참고용)**

문장: 필립스같은 유명 브랜드는 아니지만 이슈가 된 전자파테스트도 통과했다네요.
엔티티: [["브랜드#인지도", [null, 0, 0], "negative"]]

문장: 본래도 아윤채가 뷰티 유투버나 SNS에서도 핫해서 써보고 싶었거든영 ㅎ
엔티티: [["브랜드#인지도", ["아윤채", 4, 7], "positive"]]

문장: 좋아하는 코스메틱 브랜드 중 하나인 #셀라피 ..💜
엔티티: [["브랜드#일반", ["셀라피", 21, 24], "positive"]]

문장: &name&씨가 이날 장착한 패딩과 신발은 모두 #오니즈카타이거 제품이었는데요-
엔티티: [["브랜드#일반", ["오니즈카타이거", 28, 35], "positive"]]

문장: 역시 #브이티코스메틱 😘
엔티티: [["브랜드#일반", ["브이티코스메틱", 4, 11], "positive"]]

문장: 신생아부터 성인까지 안심하고 사용하는 #믿고쓰는몽디에스
엔티티: [["브랜드#일반", ["몽디에스", 26, 30], "positive"]]

문장: 4가지 패키지를 내맘대로 골라쓰는 재미까지!
엔티티: [["패키지/구성품#다양성", ["4가지 패키지", 0, 7], "positive"]]

문장: 제룰 좋아하는 노랑노랑 컬러에 디자인도 쪼꼬미라 운동 나갈 때 주머니에도 쏙~
엔티티: [["패키지/구성품#디자인", ["노랑노랑 컬러", 8, 15], "positive"], ["제품 전체#디자인", [null, 0, 0], "positive"]]

문장: 그리고 쓸데없이 비싼 부가 액세서리.
엔티티: [["패키지/구성품#가격", ["부가 액세서리", 12, 19], "negative"]]

문장: 귀여운것은 덤~~^^
엔티티: [["패키지/구성품#디자인", [null, 0, 0], "positive"]]

문장: 넘 예쁜 # #오드오랄 치약 #취향저격!
엔티티: [["패키지/구성품#디자인", ["오드오랄 치약", 8, 15], "positive"]]

문장: 패키지도 고급지고 예뻐서 #출산선물 로도 굿굿❗🤘
엔티티: [["패키지/구성품#디자인", ["패키지", 0, 3], "positive"]]

문장: 하, 포장도 이뻐요.
엔티티: [["패키지/구성품#디자인", ["포장", 3, 5], "positive"]]

문장: 물티슈는 #대디베이비 만 사용하는데 휴대용 사이즈 요거 외출할 때 진짜 편해요~ ㅋㅋ
엔티티: [["패키지/구성품#편의성", ["휴대용 사이즈", 20, 27], "positive"]]

** 지금 하나의 문장을 생성하고, 해당 문장에서 추출한 엔티티들을 다음 형식으로 출력하세요.**

문장: [자연스러운 한국어 제품 리뷰 문장]
엔티티: [["본품#편의성", [null, 0, 0], "positive"]]

반드시 이 형식을 지키고, 문장은 하나만 출력하세요.
※ 특정 브랜드(삼성, 애플 등)만 반복되지 않도록 **다양한 패키지/구성품과 브랜드**를 분산하여 사용하세요. **더 다양성을 높이세요(생전 처음보는 실제 브랜드/상품도 가능)!**
※ 감정 비율 반드시 준수: 전체 생성 문장의 감정은 반드시 **positive:neutral:negative = 0.5:2:2** 비율을 맞춰야 합니다.
'''
        
        return prompt

    def generate_data(self, num_samples: int = 10) -> List[Dict]:
        """프롬프트를 사용해 NER 데이터 생성"""
        results = []
        base_prompt = self.create_direct_entity_prompt()
        
        print(f"총 {num_samples}개의 데이터를 생성합니다...")
        
        for i in range(num_samples):
            try:
                response = self.client.chat.completions.create(
                    model=self.model,
                    messages=[
                        {"role": "system", "content": "당신은 한국어 NER 엔티티 데이터 생성 전문가입니다. 희귀 엔티티가 포함된 자연스러운 문장을 생성해야 합니다."},
                        {"role": "user", "content": base_prompt}
                    ],
                    temperature=0.8,
                    max_tokens=600
                )
                
                content = response.choices[0].message.content
                parsed_result = self.parse_direct_response(content)
                
                if parsed_result:
                    results.append(parsed_result)
                    self.results.append(parsed_result)
                    print(f"생성 완료 {i+1}/{num_samples}: {parsed_result['sentence']}")
                else:
                    print(f"파싱 실패 {i+1}/{num_samples}")
                
                time.sleep(1)
                
            except Exception as e:
                print(f"API 호출 실패 {i+1}/{num_samples}: {e}")
                continue
                
        return results

    def parse_direct_response(self, response: str) -> Dict:
        """GPT 응답을 파싱하여 엔티티 형식으로 변환"""
        lines = response.strip().split('\n')
        sentence = ""
        entities = []
        
        for line in lines:
            line = line.strip()
            if line.startswith('문장:'):
                sentence = line.replace('문장:', '').strip()
            elif line.startswith('엔티티:'):
                entities_str = line.replace('엔티티:', '').strip()
                try:
                    entities = eval(entities_str)
                except:
                    # 파싱 실패시 빈 리스트
                    entities = []
        
        # 엔티티가 없으면 None 추가
        if not entities:
            entities = [["None", [["None", 0, 0]], "neutral"]]
        
        # 검증 및 형식 확인
        if sentence and entities:
            return {
                'sentence': sentence,
                'entities': entities
            }
        else:
            return None

    def save_entity_data(self, data: List[Dict], filename: str = "direct_entity_data.json"):
        """엔티티 데이터 저장"""
        with open(filename, 'w', encoding='utf-8') as f:
            json.dump(data, f, ensure_ascii=False, indent=2)
        print(f"엔티티 데이터가 {filename}에 저장되었습니다.")

    def print_examples(self, data: List[Dict], num_examples: int = 5):
        """생성된 데이터 예시 출력"""
        print(f"\n=== 생성된 데이터 예시 ({min(num_examples, len(data))}개) ===")
        for i, item in enumerate(data[:num_examples]):
            print(f"\n{i+1}. 문장: {item['sentence']}")
            print(f"   엔티티:")
            for entity in item['entities']:
                if len(entity) >= 3:
                    entity_name, words_info, sentiment = entity[0], entity[1], entity[2]
                    print(f'     ["{entity_name}", {words_info}, "{sentiment}"]')

    def add_none_entities(self, data: List[Dict]) -> List[Dict]:
        """엔티티가 없는 경우 None 엔티티 추가"""
        for item in data:
            if not item['entities'] or len(item['entities']) == 0:
                item['entities'] = [["None", [["None", 0, 0]], "neutral"]]
        return data


# 사용 예시
if __name__ == "__main__":
    API_KEY = ""
    
    # 생성기 초기화
    generator = DirectEntityNERGenerator(API_KEY, model="gpt-4o")
    
    # 데이터 생성
    print("=== 직접 엔티티 형식 NER 데이터셋 생성 ===")
    data = generator.generate_data(num_samples=1000)  # 원하는 샘플 수로 변경
    
    # None 엔티티 처리
    data = generator.add_none_entities(data)
    
    # 생성된 데이터 예시 출력
    generator.print_examples(data)
    
    # JSON 파일로 저장
    generator.save_entity_data(data, "direct_entity_ner_data2000_3.json")
    
    print("\n=== 생성 완료 ===")
    print("direct_entity_ner_data2000_3.json - 직접 엔티티 형식 데이터")
    
    # 원하는 형식 예시 출력
    print("\n=== 원하는 형식 예시 ===")
    if data:
        example = data[0]
        print(f"문장: {example['sentence']}")
        for entity in example['entities']:
            print(f'{entity}')
# Out:
# === 직접 엔티티 형식 NER 데이터셋 생성 ===
# 총 1000개의 데이터를 생성합니다...
# 생성 완료 1/1000: 최근에 구입한 트라움 폼 매트리스, 디자인도 깔끔하고 다양한 옵션 선택이 가능해서 맘에 들어요.
# 생성 완료 2/1000: 라미 만년필의 포장은 정말 고급스러워서 선물용으로도 손색없어요.
# 생성 완료 3/1000: 최근에 구매한 리바이스 청바지의 디자인이 정말 독특하고 멋스러워요. 게다가 여러 종류의 스타일이 있어서 선택의 폭이 넓어요.
# 생성 완료 4/1000: 나이키 브랜드의 다양한 운동화 옵션이 너무 많아서 선택이 힘들었어요.
# 생성 완료 5/1000: 이케아의 다양한 가구 옵션은 정말 매력적이지만, 품절이 잦아서 아쉬워요.
# 생성 완료 6/1000: 요즘 SNS에서 핫하다는 스토케의 유모차는 디자인도 예쁘고 사용이 편해서 많은 엄마들 사이에서 인기랍니다!
# 생성 완료 7/1000: 바나나우유의 포장 디자인이 너무 귀엽고 가지고 다니기 편리해서 하루 종일 기분이 좋더라고요!
# 생성 완료 8/1000: 먼슬리랩의 패키지 디자인은 깔끔하지만 특별한 매력이 없어 보여 아쉽네요.
# 생성 완료 9/1000: 새로 나온 얼티밋 이어즈의 블루투스 스피커는 가성비가 정말 뛰어나네요, 디자인도 세련되고 만족스러워요!
# 생성 완료 10/1000: 에르메스의 다양한 액세서리는 그저 멋지다는 말밖에 안 나올 정도지만, 가격은 솔직히 너무 부담스럽네요.
# 생성 완료 11/1000: "아디다스 스포츠백은 다양한 디자인 옵션이 있어서 선택의 폭이 넓어요."
# 생성 완료 12/1000: 이케아의 다양한 수납 박스는 정말 인기가 많지만, 가격이 조금 비싼 편이에요.
# 생성 완료 13/1000: 코즈모나의 가격은 조금 부담스럽지만, 다양한 제품 옵션이 있어서 선택의 폭이 넓어요.
# 생성 완료 14/1000: 스파오의 가격은 저렴한데 디자인이 정말 세련됐어요.
# 생성 완료 15/1000: 쿠첸의 전기밥솥은 디자인이 심플하고 세련되어 주방의 분위기를 확 바꿔줘요.
# 생성 완료 16/1000: 비록 유명 브랜드는 아니지만, 타이디의 다양한 옵션과 깔끔한 디자인은 꽤 만족스러웠어요.
# 생성 완료 17/1000: 모던하우스의 인테리어 소품은 디자인이 예쁘긴 하지만 가격이 좀 비싸서 부담되네요.
# 생성 완료 18/1000: 핸드폰 케이스 브랜드 중 하나인 '케이스티파이'는 다양한 색상과 디자인 옵션이 있어 고르기 어려울 정도예요.
# 생성 완료 19/1000: 최근에 구매한 하이엔드 브랜드인 무아레의 스피커는 디자인이 너무 예뻐서 방 안 분위기가 확 살아나요.
# 생성 완료 20/1000: 미요 포장의 디자인은 정말 감각적이라 보자마자 마음에 들었어요!
# 생성 완료 21/1000: "후지필름의 인스탁스 미니 카메라는 디자인도 예쁘고 휴대성도 좋아서 여행에 꼭 들고 다녀야 해요."
# 생성 완료 22/1000: 오기노의 다양한 색상 옵션 덕분에 커스터마이징이 쉬워졌어요.
# 생성 완료 23/1000: 시장에서 알마니 향수는 꽤 유명하지만 가격이 부담스러워요.
# 생성 완료 24/1000: 톰포드 향수는 확실히 고급스럽지만, 가격이 너무 높은 것 같아요.
# 생성 완료 25/1000: 브루넬로 쿠치넬리의 가방은 디자인이 독특하고 매력적이지만, 가격은 너무 비쌉니다.
# 생성 완료 26/1000: 뱅앤올룹슨의 헤드폰은 디자인은 물론이고 다양한 컬러 옵션이 있어서 취향에 맞게 고를 수 있어요.
# 생성 완료 27/1000: 디에이치케어의 제품은 인지도가 낮아서 사람들에게 잘 알려지지 않았어요.
# 생성 완료 28/1000: 예능 프로그램에서 핫한 산타마리아노벨라 블루티 컬렉션, 디자인이 예술이라 방에 두기만 해도 분위기가 살아나요.
# 생성 완료 29/1000: 오르비스의 다양한 스킨케어 제품은 선택의 폭이 넓어서 좋아요.
# 생성 완료 30/1000: 아르마니의 최신 향수는 정말 멋지지만, 가격이 너무 높아서 쉽게 구매하기 힘드네요.
# 생성 완료 31/1000: 카카오브랜드의 새 패키지는 다양한 옵션이 있어서 선택의 폭이 넓어요.
# 생성 완료 32/1000: 최근에 구입한 마몽드 화장품의 패키지가 정말 세련되어 보여요, 화장대에도 잘 어울리네요.
# 생성 완료 33/1000: 피셔프라이스 장난감이 유명해서 많이들 사는데, 가격이 좀 비싼 것 같아요.
# 생성 완료 34/1000: 스위스밀리터리의 가방은 디자인이 단순해서 실망이었어요.
# 생성 완료 35/1000: "나혼자산다에서 소개된 바 있는 루카스캐릭터 시리즈는 디자인이 독특해서 눈길을 끌었지만, 가격이 다소 비싼 편이에요."
# 생성 완료 36/1000: 최근 구매한 #래디언스의 스킨케어 패키지는 디자인이 참 세련된 것 같아요.
# 생성 완료 37/1000: "최근에 독립 커피 브랜드 '그린빈'에서 구매한 원두 패키지는 디자인이 정말 세련됐어요, 다만 원두 종류가 한정적이라 아쉬웠어요."
# 생성 완료 38/1000: 최근에 구매한 '리틀파머스'의 유기농 주스 패키지는 디자인이 너무 심플하고 멋져서 주방에 두기만 해도 인테리어 효과가 있네요.
# 생성 완료 39/1000: 최근에 #플로리안의 다양한 향초 세트를 구매했는데, 종류가 정말 다양해서 고르기 힘들었어요.
# 생성 완료 40/1000: 오랜만에 구입한 노가디자인의 스튜디오 라이트, 이것도 역시 너무 비싸네요.
# 생성 완료 41/1000: 테팔의 프라이팬 세트는 다양한 크기와 옵션으로 요리를 즐기는 데 큰 도움이 됐어요.
# 생성 완료 42/1000: 최근에 구입한 아디다스 운동화의 디자인이 마음에 드는데, 가격이 생각보다 많이 올라서 부담스러웠어요.
# 생성 완료 43/1000: 요즘 인기 있는 라프엘트 브랜드의 가격은 좀 높지만, 디자인이 워낙 독창적이라 사람들이 많이 찾는 것 같아요.
# 생성 완료 44/1000: 최근 새로 출시한 플러그앤휴의 스마트 램프는 디자인이 독특해서 눈길을 끌었지만, 패키지 가격이 너무 높아 구매를 망설이게 되네요.
# 생성 완료 45/1000: "신발을 사려고 했는데, 타미힐피거의 디자인은 역시 고급스러워요. 근데 가격이 너무 비싸서 망설여집니다."
# 생성 완료 46/1000: 얼마 전 구매한 보이스타의 헤드폰은 디자이너의 손길이 느껴지는 고급스러운 외관이지만, 가격이 너무 비싸서 고민이 되네요.
# 생성 완료 47/1000: #스킷츠의 패키지 디자인은 정말 특별해서 매번 열 때마다 기분이 좋아요!
# 생성 완료 48/1000: 오랜만에 친구가 선물해준 이니스프리 패키지가 다채로워서 기분이 좋았어요.
# 생성 완료 49/1000: 요즘 들어 #마몽드 립스틱의 색상이 너무 다양한데, 디자인도 세련되어서 봄맞이로 딱인 것 같아요.
# 생성 완료 50/1000: 최근 롯데제과의 초코파이는 가격은 저렴하지만 포장 디자인이 너무 평범하네요.
# 생성 완료 51/1000: 마몽드의 다양한 옵션이 있지만 가격이 높아서 다소 부담스럽네요.
# 생성 완료 52/1000: 마이프로틴은 가격이 저렴하면서도 다양한 맛 선택이 가능한데, 패키지 디자인까지 너무 세련돼서 매일 마시고 싶어요.
# 생성 완료 53/1000: 얼마 전 친구가 추천해준 [알마니]의 사은품 구성이 정말 다양해서 놀랐어요.
# 생성 완료 54/1000: 이케아의 가구는 디자인은 깔끔하지만, 패키지 종류가 한정적이라 아쉽네요.
# 생성 완료 55/1000: 최근에 구입한 #몽클레어 패딩의 가격은 좀 과한 것 같아요, 브랜드명을 고려해도.
# 생성 완료 56/1000: 모던하우스의 다양한 주방용품 세트는 선택의 폭이 넓어 항상 만족스러워요.
# 생성 완료 57/1000: 이니스프리의 스킨케어 라인은 다양한 제품군이 있어 선택의 폭이 넓지만, 가격은 조금 비싼 편이에요.
# 생성 완료 58/1000: 최근에 구입한 텀블러가 너무 실망스러웠어요. #스타벅스 제품이라 디자인은 예쁜데, 가격이 비싸네요.
# 생성 완료 59/1000: 이번에 구입한 다이슨 무선청소기의 다양한 노즐 구성 덕분에 청소할 때 굉장히 편해졌어요.
# 생성 완료 60/1000: 최근에 구매한 소다스트림의 탄산수 메이커는 다양한 용량의 병이 함께 제공되어 편리하네요.
# 생성 완료 61/1000: 오리온 초코파이의 포장지는 매번 색다른 디자인으로 눈길을 끌지만 가격이 조금 부담스럽습니다.
# 생성 완료 62/1000: "다이슨의 다양한 청소기 옵션은 좋지만, 가격은 여전히 부담스럽네요."
# 생성 완료 63/1000: 발렌티노의 가방은 디자인이 너무 유니크하고, 많은 선택지가 있어 다양한 스타일링에 딱이에요.
# 생성 완료 64/1000: 메이븐코스의 패키지는 정말 세련됐지만, 가격 면에서 아쉬운 점이 있네요.
# 생성 완료 65/1000: "요즘 #이니스프리 화장품이 가격대비 성능이 좋다는 소문이 많던데, 정작 브랜드 인지도는 생각보다 낮은 것 같아요."
# 생성 완료 66/1000: 요즘 무인양품의 패키지가 너무 평범해서 감흥이 없어요.
# 생성 완료 67/1000: 에어팟과는 다르게 #아이헤드폰 은 스타일 면에서는 조금 아쉽네요.
# 생성 완료 68/1000: 요즘 핫한 '플로렌스'의 화장품 패키지는 디자인이 세련되었지만 사용하기 불편해서 좀 아쉬워요.
# 생성 완료 69/1000: 퓨리나의 강아지 사료는 다양한 옵션이 있어서 여러 견종에게 적합해요.
# 생성 완료 70/1000: 라뮤즈는 제품은 만족스럽지만 가격이 조금 부담스럽네요.
# 생성 완료 71/1000: 이케아의 테이블 조립이 간편해서 혼자서도 쉽게 설치할 수 있었어요.
# 생성 완료 72/1000: "최근에 출시된 샤넬의 향수 패키지는 가격 대비 옵션이 너무 부족해서 아쉬워요."
# 생성 완료 73/1000: 애틀랜타 브랜드의 디자인은 깔끔하지만, 가격대가 높아 접근하기 부담스러워요.
# 생성 완료 74/1000: 친구한테 선물 받은 러쉬의 패키지가 생각보다 다양해서 놀랐어요.
# 생성 완료 75/1000: 스컬캔디의 이어폰은 디자인은 세련되었지만 브랜드 자체의 인지도는 의외로 낮네요.
# 생성 완료 76/1000: 이케아의 가구는 가격 대비 디자인은 괜찮지만, 종류가 다양하지 않아 조금 아쉽다.
# 생성 완료 77/1000: 드디어 구입한 모모랜드의 노트북, 디자인은 예쁘지만 다소 비싸네요.
# 생성 완료 78/1000: 요즘 파카 브랜드의 볼펜은 디자인이 무난한데, 가격이 은근히 비싸서 고민 중이에요.
# 생성 완료 79/1000: 최근 알게 된 떠오르는 브랜드 '다이슨'의 청소기는 정말 하이테크 디자인이네요. 하지만 가격은 조금 부담스럽네요.
# 생성 완료 80/1000: 최근 입문한 브랜드인 '마르카토'는 제품 가격이 지나치게 높아 가성비가 아쉽습니다.
# 생성 완료 81/1000: "밀코티의 가격은 좀 비싼 편이라 가성비가 떨어진다고 느껴졌어요."
# 생성 완료 82/1000: 친구가 선물해준 #비비안웨스트우드 패키지가 너무 예뻐서 감동했어요!
# 생성 완료 83/1000: 신생 브랜드인 마이멜로우 제품의 가격이 상당히 높아서 구매를 망설이게 되네요.
# 생성 완료 84/1000: 트렌디한 디자인의 나이키 운동화는 가격대가 조금 부담스럽네요.
# 생성 완료 85/1000: 브랜드 인지도가 높은 나이키이지만, 최근 신발 디자인은 특별히 끌리지 않는 것 같아요.
# 생성 완료 86/1000: 최근에 알게 된 브랜드, #테이스트리의 과일 스낵은 참신한 디자인이 매력적이지만, 가격이 조금 부담스럽네요.
# 생성 완료 87/1000: 요즘 스포티파이의 다양한 음악 추천 알고리즘 덕분에 새로운 곡을 많이 알게 됐어요.
# 생성 완료 88/1000: 요즘 웨일스 브랜드의 제품은 트렌디한 디자인으로 인기가 많지만, 가격이 은근히 비싼 편이에요.
# 생성 완료 89/1000: 다소 비싼 가격이지만, 도요타의 차량은 디자인이 세련되어 주목 받는 것 같아요.
# 생성 완료 90/1000: 롯데제과의 과자 패키지가 확실히 다양해서 아이들 간식 선택에 폭이 넓어요.
# 생성 완료 91/1000: "파우치에 쉽게 넣을 수 있는 #더블에이 노트북 파우치, 덕분에 출퇴근이 한결 수월해졌어요."
# 생성 완료 92/1000: HAY의 제품은 디자인이 독특하고, 어디에 두어도 잘 어울리는 것 같아요.
# 생성 완료 93/1000: 다이소의 문구류는 가격이 매우 저렴한데, 디자인은 다소 아쉽네요.
# 생성 완료 94/1000: 에이프릴스킨의 스킨케어 패키지는 다양한 옵션이 있어서 피부 타입에 맞춰 선택할 수 있어요.
# 생성 완료 95/1000: 아디다스의 최신 운동화는 디자인 면에서는 탁월하지만, 가격이 너무 높아서 구매하기가 망설여집니다.
# 생성 완료 96/1000: 최근에 구입한 라이카 카메라의 패키지는 정말 실망스러웠어요. 구성품이 너무 빈약해서 추가 비용을 들여야 할 판입니다.
# 생성 완료 97/1000: 삼성의 최신 스마트폰은 다양한 색상 옵션이 제공되어 선택의 폭이 넓어 정말 만족스러웠어요.
# 생성 완료 98/1000: 이케아의 제품은 디자인이 단순하지만, 패키지의 조립법이 너무 복잡해서 불편해요.
# 생성 완료 99/1000: 요즘 트렌드에 맞지 않은 디자인의 리바이스 청바지라 인기가 떨어진 느낌이에요.
# 생성 완료 100/1000: ROEN의 스크린 보호필름은 품질은 괜찮지만 디자인은 별로라 구매할 때 망설였어요.
# 생성 완료 101/1000: 최근 구매한 라이카 카메라의 다양한 액세서리는 구성물이 많아 처음엔 좀 복잡했지만, 차근차근 사용해보니 편리함이 느껴졌어요.
# 생성 완료 102/1000: 요즘 코코도르의 가격이 조금씩 올라서 구매할 때 신중하게 고민하게 되네요.
# 생성 완료 103/1000: 최근에 구매한 반스 스니커즈는 다양한 색상 옵션이 있어서 선택의 폭이 넓어서 좋았어요.
# 생성 완료 104/1000: 파타고니아는 가격이 꽤나 높은 편이라 부담스러울 수도 있어요.
# 생성 완료 105/1000: 베어벨스의 프로틴바는 맛 선택의 폭이 넓어서 매번 다른 맛을 시도할 수 있어서 좋아요.
# 생성 완료 106/1000: 펜텔의 볼펜은 가격은 좋지만 디자인이 평범해서 사람들 사이에서 그다지 인기를 끌지 못하고 있어요.
# 생성 완료 107/1000: 안다르의 요가복은 스타일리시한 디자인으로 요가할 때도 멋스럽고, 일상에서도 입기 좋은 편안함을 제공해요.
# 생성 완료 108/1000: 안다르의 요가 매트는 디자인이 세련되지만, 가격이 좀 비싸요.
# 생성 완료 109/1000: 비록 널리 알려지지 않은 브랜드인 파운데이션이지만, 가성비 하나는 정말 끝내주네요.
# 생성 완료 110/1000: 아비노의 핸드크림은 가격이 저렴해서 부담 없이 사용할 수 있어요.
# 생성 완료 111/1000: 지비츠의 다양한 옵션 덕분에 크록스에 개성을 더할 수 있어요.
# 생성 완료 112/1000: 올리브영에서 산 리르 립&아이 리무버는 저렴한 편이라서 부담이 없어요.
# 생성 완료 113/1000: 베이비올리브의 패키지 디자인은 정말 세련되고 고급스러워서, 선물용으로 딱이에요.
# 생성 완료 114/1000: 요즘 델타크루즈 브랜드가 꽤 인지도가 높아졌지만 가격대가 좀 부담스럽네요.
# 생성 완료 115/1000: 파리바게트의 다양한 빵 종류가 정말 놀랍지만, 가격 면에서는 조금 부담스럽네요.
# 생성 완료 116/1000: 요즘 타이포그라피로 유명한 핫디자인의 포스터는 가격이 좀 나가지만, 그만큼 퀄리티가 확실히 좋아요.
# 생성 완료 117/1000: 요즘 들어 마켓컬리의 식품 패키지가 너무 예뻐서, 선물하기에도 좋겠다는 생각이 듭니다.
# 생성 완료 118/1000: 최근 구매한 맨소래담 립밤의 패키지는 다양한 색상과 디자인으로 선택의 폭이 넓어서 좋아요.
# 생성 완료 119/1000: 리바이스 청바지는 디자인이 예쁘긴 하지만 가격이 너무 비싸서 구매를 망설이게 돼요.
# 생성 완료 120/1000: 루이까또즈의 가방은 디자인이 세련되었지만 가격이 너무 비싸서 구매에 망설여지네요.
# 생성 완료 121/1000: 최근에 구매한 텐마루 가방의 디자인이 너무 독특해서 친구들 사이에서도 화제가 되었어요.
# 생성 완료 122/1000: 아무래도 토니모리의 제품은 디자인이 평범해서 딱히 눈에 띄지 않네요.
# 생성 완료 123/1000: BOB 제품은 인기도는 높지 않지만, 여러 가지 색상 옵션이 있어 선택의 폭이 넓어요.
# 생성 완료 124/1000: 마르헨제이 가방의 다양한 컬러와 디자인은 참신하지만 가격이 너무 높아서 아쉬워요.
# 생성 완료 125/1000: 요즘 렌즈미의 다양한 컬러 렌즈가 예쁘다고 하던데, 특히 이번에 나온 패키지 디자인이 인기가 많더라고요.
# 생성 완료 126/1000: 알고코스메틱의 스킨케어 제품들은 가격대가 굉장히 합리적이라 학생들에게도 유명합니다.
# 생성 완료 127/1000: "최근에 구입한 마이어스의 향수는 패키지 디자인이 너무 예쁘네요. 선물용으로도 정말 좋은 것 같아요!"
# 생성 완료 128/1000: 요즘 들어 파브롯소의 다채로운 디자인이 정말 마음에 들어요, 특히 휴대폰 케이스 옵션이 다양해서 고르기가 어려웠어요.
# 생성 완료 129/1000: 비록 다른 브랜드만큼의 인지도를 가진 것은 아니지만, '세라스'의 디자인은 정말 독특하고 매력적이에요.
# 생성 완료 130/1000: '이솝'의 다양한 제품 라인은 정말 감탄스러워요, 특히 스킨케어 옵션이 많아 선택의 폭이 넓어요.
# 생성 완료 131/1000: 최근에 구매한 무헤이 스피커는 가격 대비 성능이 뛰어나지만 디자인 면에서는 조금 아쉬움이 남네요.
# 생성 완료 132/1000: 토리버치 가방은 디자인이 세련되었지만, 가격이 너무 부담스럽네요.
# 생성 완료 133/1000: 요즘 스웨덴 브랜드 '클라르나'의 결제 서비스는 편리하지만, 상대적으로 인지도가 낮은 편이에요.
# 생성 완료 134/1000: "피치스킨의 새로운 립밤은 색상 선택이 다양해서 좋지만, 가격이 좀 높다고 느껴져요."
# 생성 완료 135/1000: 최근에 구매한 QCY 이어버드의 다양한 색상 옵션은 정말 마음에 들어요.
# 생성 완료 136/1000: 엘레쎄의 운동복은 가격대가 생각보다 비싸서 아쉬웠어요.
# 생성 완료 137/1000: 비트윈 시리즈의 노트는 디자인이 참 예쁜데 가격이 좀 부담스럽네요.
# 생성 완료 138/1000: 아이허브에서 구입한 비타민 패키지는 구성품이 다양해서 선택의 폭이 넓어요.
# 생성 완료 139/1000: 최근에 구매한 키엘의 스킨케어 제품은 패키지가 너무 예뻐서 선물용으로도 좋을 것 같아요.
# 생성 완료 140/1000: 아무래도 마이셰프의 식품 패키지는 종류가 다양해서 선택의 폭이 넓어요.
# 생성 완료 141/1000: 요즘 릴리프 패션 브랜드가 인기라는데, 특히 디자인이 무난해서 별로 눈에 띄지 않는 것 같아요.
# 생성 완료 142/1000: 최근에 #하이브리드패치의 포장디자인이 너무 복잡해서 열 때마다 불편해요.
# 생성 완료 143/1000: "고객들이 바라는 다양한 스타일을 제공하는 #아디다스 스니커즈는 선택의 폭이 넓어 만족스러워요."
# 생성 완료 144/1000: 파워컴퓨팅의 다양한 PC 구성품들이 많이 있지만, 가격대가 전반적으로 높아서 구매를 망설이게 돼요.
# 생성 완료 145/1000: 아디다스는 다양한 디자인의 운동화를 제공하여 선택의 폭이 넓어 좋긴 한데, 가격이 비싸서 부담됩니다.
# 생성 완료 146/1000: 아이오페는 디자인이 예쁘긴 한데, 가격이 너무 비싸서 조금 부담스럽네요.
# 생성 완료 147/1000: 최근에 핫하다는 코코넛의 스킨케어 세트는 패키지 디자인이 정말 매력적이더라구요!
# 생성 완료 148/1000: 다이소의 다양한 문구 패키지는 선택의 폭이 넓어서 만족스럽습니다.
# 생성 완료 149/1000: 이번에 구매한 마몽드의 뷰티박스는 패키지가 다양해서 골라쓰는 재미가 있네요.
# 생성 완료 150/1000: "푸마의 다양한 운동화 컬렉션은 선택의 폭이 넓어 다양한 스타일을 만날 수 있어서 좋습니다."
# 생성 완료 151/1000: 요즘 SNS에서 화제가 된 샤넬의 액세서리가 인기가 많지만, 가격이 너무 비싸요.
# 생성 완료 152/1000: 마우리의 에코 프렌들리 패키지는 환경을 생각한 디자인과 다양한 선택 옵션으로 마음에 듭니다.
# 생성 완료 153/1000: 최근 구매한 벤타 냉풍기, 상대적으로 저렴한 가격이지만 성능은 훌륭하네요.
# 생성 완료 154/1000: 최근 알게 된 플랜트베리 제품은 비록 가격은 조금 높지만, 독특한 디자인과 편리한 패키지가 큰 매력 포인트에요.
# 생성 완료 155/1000: 마스카라는 비싼데, 에스쁘아의 브러쉬 종류가 다양해서 선택할 때 고민이 많았어.
# 생성 완료 156/1000: 최근에 다이슨 제품이 워낙 유명해서 구매했는데, 가격이 비싸서 조금 망설여졌어요.
# 생성 완료 157/1000: 최근에 사용해본 '에코백스 로봇청소기'의 패키지는 너무 복잡해서 설치하는데 시간이 너무 많이 걸렸어요.
# 생성 완료 158/1000: 최근에 구입한 바닐라코의 스킨케어 라인은 디자인이 정말 별로였어요.
# 생성 완료 159/1000: 최근에 구매한 록시땅 핸드크림의 다양한 향이 마음에 드는데, 특히 라벤더 향이 좋아요.
# 생성 완료 160/1000: 최근에 #라네즈의 다양한 립밤 컬렉션을 구입했는데, 종류가 많아서 골라 쓰는 재미가 있네요.
# 생성 완료 161/1000: 최근에 #자이언트바이크 구매했는데, 다양한 모델과 옵션이 많아서 고르는데 좀 어지러웠어요.
# 생성 완료 162/1000: 정관장의 다양한 홍삼 제품은 옵션이 많아서 고르기가 어려워요.
# 생성 완료 163/1000: 무인양품의 패키지는 깔끔한 디자인으로 유명하지만 가격이 조금 부담스럽죠.
# 생성 완료 164/1000: 최근에 구입한 모모코의 스카프 패키지는 색상이 너무 제한적이었어요.
# 생성 완료 165/1000: 아리따움의 립스틱은 다양한 색상과 디자인으로 매번 구매할 때마다 새로운 느낌이에요.
# 생성 완료 166/1000: 텀블러를 구매했는데, 조셉조셉의 디자인이 정말 예쁘고 색상도 다양해서 선택의 폭이 넓어요.
# 생성 완료 167/1000: 루미스파의 디자인은 나쁘지 않지만, 다양한 색상이 없어서 아쉬워요.
# 생성 완료 168/1000: 애플의 다양한 색상 옵션 덕분에 아이폰 14의 디자인은 시각적으로 정말 매력적이에요.
# 생성 완료 169/1000: 파타고니아의 산뜻한 색감과 유니크한 디자인이 매력적이지만 가격이 조금 부담스러워요.
# 생성 완료 170/1000: 티에리 뮈글러의 향수는 가격 대비 가성비가 별로라는 생각이 드네요.
# 생성 완료 171/1000: 요즘 친구들 사이에서 #요기보라 그래놀라바가 핫한데, 포장 디자인이 너무 세련되어서 선물하기에도 좋아요.
# 생성 완료 172/1000: 소니의 액세서리 패키지는 종류가 다양해서 선택의 폭이 넓어요.
# 생성 완료 173/1000: 다이소의 사은품 구성은 종류가 너무 제한적이라 아쉽네요.
# 생성 완료 174/1000: 레페토의 발레 슈즈는 가격이 비싸다고 들었지만, 그 편안함과 디자인은 정말 특별해요.
# 생성 완료 175/1000: 루디스의 가방은 디자인이 독창적이어서 보기만 해도 기분이 좋아져요.
# 생성 완료 176/1000: 최근에 산 "타이니 레이블"의 칫솔 패키지, 여러 가지 색상 덕분에 매일 기분에 따라 선택할 수 있어서 좋네요.
# 생성 완료 177/1000: 최근에 살롱드메르의 헤어 트리트먼트를 사용해봤는데, 가격이 조금 부담스럽더라고요.
# 생성 완료 178/1000: 새로운 필사노트의 디자인이 너무 예뻐서, 필사할 때마다 기분이 좋아져요.
# 생성 완료 179/1000: 키보드 커버의 미적 디자인이 마음에 들지만, 가격이 조금 아쉬워요.
# 생성 완료 180/1000: 다양한 옵션을 제공하는 모나미의 문구 패키지는 선택의 폭이 넓어서 구매자에게 큰 장점이에요.
# 생성 완료 181/1000: 가격은 조금 비싸지만 프리미엄 브랜드인 키엘의 스킨케어 세트는 그만큼의 가치가 있다고 생각해요.
# 생성 완료 182/1000: 브로콜리랩의 패키지는 너무 복잡해서 사용하기 불편해요.
# 생성 완료 183/1000: 리안파르틴의 다양한 향수 컬렉션은 선택의 폭이 넓어서 정말 좋아요.
# 생성 완료 184/1000: 요즘 SNS에서 많이 보이는 무지 패키지, 디자인이 깔끔해서 좋긴 한데 다른 색상 옵션이 있었으면 더 좋았을 것 같아요.
# 생성 완료 185/1000: 루나 솔로의 패키지는 디자인이 단조로워서 별로 눈에 띄지 않네요.
# 생성 완료 186/1000: 요즘 메타몹스의 제품은 참신한 디자인 덕분에 눈길을 끌고 있어요.
# 생성 완료 187/1000: 최근에 구입한 '휴대용 발열 패드'는 너무 비싸서 다시는 살 생각이 없네요.
# 생성 완료 188/1000: 넥소의 패키지는 깔끔한데 가격은 다른 브랜드에 비해 조금 비싼 감이 있어요.
# 생성 완료 189/1000: 이번에 구매한 따수미 이불은 가격이 꽤 비싸지만, 디자인이 정말 고급스럽고 마음에 들어요.
# 생성 완료 190/1000: 가성비로 유명한 노브랜드 제품은 패키지 디자인이 단순해서 특별함은 없지만 다양한 선택지가 있어요.
# 생성 완료 191/1000: 델몬트의 다양한 주스 종류는 언제나 선택의 폭이 넓어 좋네요.
# 생성 완료 192/1000: 레고의 새로운 컬렉션은 종류가 다양해서 아이들이 질리지 않고 놀 수 있어요.
# 생성 완료 193/1000: 알로에 성분이 포함된 네이쳐리퍼블릭의 화장품 패키지는 너무 매력적이지만, 가격대가 너무 높아서 부담돼요.
# 생성 완료 194/1000: 코스타커피의 텀블러는 디자인이 세련되긴 하나, 사용하기에는 조금 불편하네요.
# 생성 완료 195/1000: 뷰티 블렌더의 다양한 색상 선택지가 있어서 기분에 따라 매일 다른 색상으로 메이크업이 가능해요.
# 생성 완료 196/1000: 생각보다 가격이 괜찮아서 레이디가구 소파 세트 구매했는데, 디자인도 나쁘지 않아요.
# 생성 완료 197/1000: 다이소의 다양한 주방용품은 저렴한 가격에 많은 선택지를 제공하지만 디자인은 다소 투박한 편입니다.
# 생성 완료 198/1000: 몬스터에너지는 디자인은 화려하지만, 가격이 조금 부담스러워요.
# 생성 완료 199/1000: 프라다 가방의 디자인은 정말 세련되고 고급스러워서 어디서든 주목받아요.
# 생성 완료 200/1000: 대림바이크의 가격대는 다소 비싸지만, 요즘 인지도가 높아지는 것 같아요.
# 생성 완료 201/1000: 오랜만에 구입한 미르의 호두과자 패키지는 깔끔하고, 다양한 맛을 선택할 수 있어서 좋아요!
# 생성 완료 202/1000: 최근에 핸드백을 샀는데, 프리미엄 트렌드의 핸드백이었음에도 불구하고 잭앤질의 가격은 참 착하더라.
# 생성 완료 203/1000: 최근에 알게 된 나르샤의 치약은 가격 대비 꽤 괜찮은 가성비를 보여주는 것 같아요.
# 생성 완료 204/1000: 최근에 구매한 마몽드의 립스틱 패키지가 너무 예뻐서 자꾸 들여다보게 되네요.
# 생성 완료 205/1000: 프라이탁 가방은 디자인이 독특하고 스타일리시해서 특히 젊은 층에게 인기가 많아요.
# 생성 완료 206/1000: 스테들러 연필 세트는 다양한 종류가 있어서 선택의 폭이 넓어요.
# 생성 완료 207/1000: "무지노트는 정말 디자인이 깔끔하고 심플해서 누구나 좋아할 것 같아요."
# 생성 완료 208/1000: 탠덤의 외장하드는 디자인은 깔끔하지만 가격이 좀 비싼 것 같아요.
# 생성 완료 209/1000: 최근에 구매한 하이킹 브랜드 '빅 아그네스'의 텐트는 가격이 너무 비싸서 좀 부담스럽습니다.
# 생성 완료 210/1000: 크록스는 편리함으로 유명하지만, 가격이 경쟁 브랜드에 비해 꽤 높은 편이에요.
# 생성 완료 211/1000: 다이소의 다양한 포장지 디자인은 무난하지만, 특별히 인상적이지는 않네요.
# 생성 완료 212/1000: 로레알의 신상품 컨디셔너의 다양한 향기가 정말 마음에 들어요!
# 생성 완료 213/1000: 이번에 출시된 오하라의 이중잠금 패키지, 디자인이 독특해서 눈길이 가더라구요.
# 생성 완료 214/1000: 에코백스 로봇청소기의 부품들이 다양해서, 사용자 맞춤형으로 구매할 수 있어요.
# 생성 완료 215/1000: 에스티 로더의 패키지 디자인은 정말 고급스러워서 선물용으로도 제격이에요.
# 생성 완료 216/1000: 이케아 가구는 디자인이 심플하고 다양한 스타일 선택이 가능하지만, 가격이 생각보다 저렴하지 않네요.
# 생성 완료 217/1000: 시몬스 매트리스는 고가지만 가격 대비 성능이 뛰어나다는 평가를 받습니다.
# 생성 완료 218/1000: ABC스포츠의 운동화는 디자인은 예쁜데 가격은 조금 비싸네요.
# 생성 완료 219/1000: "오세븐의 신발은 디자인이 멋지지만 가격이 비싸서 망설였어요."
# 생성 완료 220/1000: 지엔느의 실크 빌 패키지는 색상과 디자인이 너무 참신해서 데코용으로 딱이네요!
# 생성 완료 221/1000: 다이슨의 드라이어는 디자인이 깔끔하고 현대적이어서 매우 만족스럽습니다.
# 생성 완료 222/1000: 아디다스 슈퍼스타 신발은 디자인은 예쁜데, 다른 브랜드에 비해 가격이 좀 비싼 것 같아요.
# 생성 완료 223/1000: 로레알의 다양한 헤어 컬러링 제품들은 항상 새로운 스타일을 시도할 수 있게 해줘요.
# 생성 완료 224/1000: 이케아의 다양한 가구 옵션은 정말 만족스러웠어요, 하지만 가격이 조금 부담스럽네요.
# 생성 완료 225/1000: 애플 제품은 디자인이 예쁘지만, 가격이 너무 비싼 것 같아요.
# 생성 완료 226/1000: 갤럭시 워치 패키지는 다양한 색상과 디자인으로 선택의 폭이 넓어서 마음에 들어요.
# 생성 완료 227/1000: 헤이딜리버리의 포장 박스는 종류가 많아서 원하는 스타일로 골라보는 재미가 있네요.
# 생성 완료 228/1000: 요즘 조립식 가구로 핫한 이케아지만, 가격이 조금 부담스럽네요.
# 생성 완료 229/1000: 삼성전자의 새로운 스마트폰은 디자인이 세련되긴 했지만, 가격이 상당히 부담스럽다.
# 생성 완료 230/1000: 최근 핫하다는 라라펫의 강아지 간식 패키지는 종류가 많아서 선택하기 좋더라고요.
# 생성 완료 231/1000: 새로운 콜맨 텐트는 다양한 색상과 디자인으로 출시되어 선택의 폭이 넓어졌어요.
# 생성 완료 232/1000: 제로큐브의 패키지는 다채로운 색상 선택이 가능해서 개인 취향에 맞춰 고를 수 있습니다.
# 생성 완료 233/1000: "이 신일전자 선풍기는 디자인이 별로지만, 다양한 색상 옵션이 있어 선택의 폭이 넓어요."
# 생성 완료 234/1000: 최근에 구입한 오리진스의 제품은 디자인이 정말 멋지지만, 가격은 좀 비싼 편인 것 같아요.
# 생성 완료 235/1000: 립톤의 다양한 허브티 옵션이 너무 만족스럽고, 가성비도 뛰어나서 요즘 매일 마시고 있어요.
# 생성 완료 236/1000: 오랜만에 이케아에서 구매한 가구인데, 가격 대비 디자인이 세련되고 활용성도 좋아요.
# 생성 완료 237/1000: 널디의 새로운 컬렉션은 선택의 폭이 넓어서 다양한 스타일을 즐길 수 있어요.
# 생성 완료 238/1000: 최근에 발견한 '더모바일'은 가격 대비 성능이 괜찮은 것 같아요. 다양한 옵션 덕분에 소비자의 선택 폭이 넓어져서 좋네요!
# 생성 완료 239/1000: 레고의 새로운 테크닉 세트는 부품의 다양성 면에서 확실히 최악이에요. 다른 옵션이 거의 없네요.
# 생성 완료 240/1000: 포르쉐의 최신 모델, 하지만 가격이 너무 비싸서 아쉽습니다.
# 생성 완료 241/1000: 최근에 구매한 노르디스크의 캠핑 의자는 디자인은 좋지만, 가격이 좀 비싸다는 느낌이 있더라고요.
# 생성 완료 242/1000: 빌리지11팩토리의 향수는 예쁘긴 한데 너무 비싸서 선뜻 구매하기가 망설여져요.
# 생성 완료 243/1000: 다이소에서 파는 귀여운 패키지 디자인의 주방용품, 가격도 착해서 매번 구매하게 되네요.
# 생성 완료 244/1000: 리안나의 새로운 헤어 오일은 포장이 참 세련되어 보이지만 가격이 조금 비싸네요.
# 생성 완료 245/1000: 요즘 클라란스의 스킨케어 제품이 핫하다고 해서 구매했는데, 패키지 디자인이 단순하고 세련된 느낌이라 굉장히 만족스러워요.
# 생성 완료 246/1000: 루나솔의 새로운 아이섀도 컬렉션은 색상 선택의 폭이 넓어서 여러 가지 스타일을 연출할 수 있어요!
# 생성 완료 247/1000: 최근에 구입한 #미니멜로우 가구의 디자인이 너무 매력적이더라구요. 하지만 구성품이 다양하지 않아 조금 아쉬웠어요.
# 생성 완료 248/1000: Humblebrush 치약 세트는 디자인이 깔끔하고 미니멀해서 화장실에 두기에도 좋아요.
# 생성 완료 249/1000: 최근에 구매한 마리끌레르 향수는 패키지 디자인이 너무 예뻐서 선물하기에도 딱이에요!
# 생성 완료 250/1000: 파블로바의 화장품 패키지가 다양한 디자인으로 나와서 선택의 폭이 넓어요.
# 생성 완료 251/1000: 아이템을 구매했는데, 메이든의 패키지 구성이 너무 단조롭고 별로인 것 같아요.
# 생성 완료 252/1000: 최근에 메디힐 이면 마스크팩 종류도 정말 많아서 선택하는 재미가 있더라고요.
# 생성 완료 253/1000: 그린플래닛의 친환경 포장재는 다양성에서는 좀 아쉽지만, 사용하기에는 너무 편리하네요.
# 생성 완료 254/1000: 로모그래피 카메라의 패키지는 다양한 필터와 컬러 옵션이 많아, 선택의 폭이 넓어요.
# 생성 완료 255/1000: 세라젬의 패키지가 다양해서 선택할 때 고민이 되긴 했지만, 여러 옵션 덕분에 적절한 선택이 가능했습니다.
# 생성 완료 256/1000: 요즘 하이센스 TV가 인지도가 높아졌다고 하더라구요, 가격도 저렴해서 더 매력적이에요.
# 생성 완료 257/1000: 최근에 알게 된 세이코 브랜드의 시계 디자인이 참 세련되고 고급스럽더라구요.
# 생성 완료 258/1000: 노르딕스포츠는 최근 다양한 스포츠 용품을 출시했지만 가격이 다소 부담스럽네요.
# 생성 완료 259/1000: 최근에 알게 된 패션 브랜드 '쿠타'가 디자인은 세련됐지만, 솔직히 가격이 좀 부담스럽네요.
# 생성 완료 260/1000: 최근에 알게 된 국내 화장품 브랜드인 아비브는 패키지 디자인이 정말 세련되고 독특해서 눈에 띄어요.
# 생성 완료 261/1000: 최근에 구입한 아보카도브랜드의 샴푸, 가격은 조금 비싼 편이라 생각했는데 역시 브랜드 파워가 있는 제품이네요.
# 생성 완료 262/1000: 요즘 들어 #비비안의 패키지가 너무 화려해서 오히려 구매 결정에 망설여지네요.
# 생성 완료 263/1000: "사실 에디슨 장난감의 디자인은 좀 촌스러워서 아이들도 별로 안 좋아해요."
# 생성 완료 264/1000: 최근에 알게 된 "벨리니어"는 브랜드는 모르겠지만, 포장 디자인이 아주 세련되어 보였어요.
# 생성 완료 265/1000: DHC의 패키지는 다양성 면에서는 조금 아쉬워요, 선택의 폭이 좁거든요.
# 생성 완료 266/1000: 요즘 가성비로 유명한 '드보라잇' 가방은 디자인도 세련되고 가격도 저렴해서 지갑이 안 아파요.
# 생성 완료 267/1000: 요즘 매장에서 많이 보이는 #멜릭서 스킨케어 제품은 디자인이 깔끔해서 마음에 들어요.
# 생성 완료 268/1000: 모나미의 다양한 색상 볼펜 세트는 필기할 때 색다른 재미를 줘요!
# 생성 완료 269/1000: 아모레퍼시픽의 다양한 뷰티 제품들은 선택할 수 있는 옵션이 많아서 좋지만, 가격이 조금 높은 편이네요.
# 생성 완료 270/1000: 최근에 구입한 윌리엄스 소노마의 주방용품은 디자인이 세련되긴 했지만 가격이 너무 높아 고민이었어요.
# 생성 완료 271/1000: 아르마니 시계의 다양한 컬러 옵션은 좋은데 가격이 너무 비싸서 아쉽네요.
# 생성 완료 272/1000: 레고사의 다양한 테마들은 선택의 폭이 넓어서 뭐든 원하는 걸 찾을 수 있어요.
# 생성 완료 273/1000: 엘레컴의 다양한 스마트폰 케이스는 디자인도 세련됐지만, 가격이 조금 비싼 편이에요.
# 생성 완료 274/1000: 리멘트의 미니어처 피규어 시리즈는 다양성이 너무 부족해서 매번 똑같은 것만 사야 하는 느낌이에요.
# 생성 완료 275/1000: 최근에 알게 된 스튜디오 오타마의 포장 디자인은 정말 감각적이었어요. 하지만 가격이 좀 비싸서 아쉬웠어요.
# 생성 완료 276/1000: 에크몰리의 헤어 악세서리는 디자인은 예쁘지만 가격이 너무 비싸요.
# 생성 완료 277/1000: 최근에 구매한 샌드박스 스마트워치의 다양한 스트랩 옵션 덕분에 매일 다른 스타일을 즐길 수 있어요.
# 생성 완료 278/1000: 마몽드의 스킨케어 세트는 디자인이 너무 평범해서 특별한 느낌이 없어요.
# 생성 완료 279/1000: 세정력이 뛰어나기로 유명한 피죤은 가격 대비 성능이 좋은 편이지만, 다양한 향이 좀 부족한 느낌이에요.
# 생성 완료 280/1000: 도루코 면도기는 가격대가 너무 높아서 다른 제품을 고려하고 있어요.
# 생성 완료 281/1000: 로레알의 가격은 비교적 저렴한 편이라 가성비가 좋은 것 같아요.
# 생성 완료 282/1000: 비록 가격이 조금 비싸지만, 마이클코어스의 핸드백 디자인은 정말 매력적이에요.
# 생성 완료 283/1000: 요새 온라인에서 핫한 '다채로운' 브랜드의 다양한 색상 옵션이 정말 많아서 선택할 수 있는 재미가 쏠쏠해요.
# 생성 완료 284/1000: 멜리사앤더그의 목공놀이 세트는 다양한 구성품과 함께 아이들의 창의력을 키우기 위한 완벽한 선택입니다.
# 생성 완료 285/1000: 최근에 구매한 소네트의 스케치북은 디자인이 정말 다양해서 선택하는 재미가 있었어요.
# 생성 완료 286/1000: 시세이도 제품의 포장 디자인이 깔끔하고 모던해서 한눈에 쏙 들어왔어요.
# 생성 완료 287/1000: 요가복 브랜드 요가디바의 디자인이 화려해서 운동할 때마다 기분이 좋아져요.
# 생성 완료 288/1000: 매번 #모노빈 의 디자인이 참신하고 독특해서 지갑이 열려요.
# 생성 완료 289/1000: 드디어 에스티로더의 새로운 립스틱 패키지를 손에 넣었는데, 디자인이 너무 고급스러워서 기분이 좋네요.
# 생성 완료 290/1000: 아크네 스튜디오의 가격이 싸진 않지만, 그만큼 고급스러운 디자인이라서 만족스러워요.
# 생성 완료 291/1000: 텀블러브랜드의 텀블러는 #디자인이 독특하고 실용성도 뛰어나지만, 가격대가 꽤 높아서 고민되네요.
# 생성 완료 292/1000: 새로운 브랜드인 '하리보'의 다양한 젤리 패키지는 색상이 다채로워 시각적으로 즐거움을 줍니다.
# 생성 완료 293/1000: 오랜만에 코코도르 디퓨저를 샀는데, 패키지가 다채로워서 선물하기도 좋네요.
# 생성 완료 294/1000: 새로운 스타일로 출시된 니베아의 한정판 색조 패키지는 디자인이 독특하지만, 실용성은 부족한 것 같아요.
# 생성 완료 295/1000: 슈퍼소닉의 디자인은 참신하지만 아직 대중에게 널리 알려지지 않은 것이 아쉬워요.
# 생성 완료 296/1000: 최근에 구매한 #카야 크림세트는 가격 대비 다양한 구성품 덕분에 만족스럽습니다.
# 생성 완료 297/1000: 페리오 치약은 저렴한 가격에 다양한 맛을 제공해서 선택의 폭이 넓네요.
# 생성 완료 298/1000: B4U의 디자인은 세련되지만, 가격이 워낙 비싸서 구매를 망설이게 되네요.
# 생성 완료 299/1000: 요즘 쿠쿠전자의 공기청정기가 가격 대비 좋다는 말을 많이 들어서 고민 중이에요.
# 생성 완료 300/1000: 레고의 다양한 세트는 아이들에게 창의력을 키워주고, 부모들이 선택할 수 있는 폭이 넓어서 좋아요.
# 생성 완료 301/1000: 레노보의 노트북은 인지도가 낮아서 사람들이 잘 모르지만, 가격 대비 성능은 괜찮은 편이에요.
# 생성 완료 302/1000: 크리스찬 디올의 화장품 포장은 정말 감각적이고 세련되었어요, 선물용으로 딱이죠.
# 생성 완료 303/1000: 모노디자인의 노트북 가방은 다양한 컬러 옵션이 없어서 아쉽네요.
# 생성 완료 304/1000: 신제품으로 나온 이케아의 조립식 가구는 디자인은 무난하지만 조립 설명서가 너무 복잡해요.
# 생성 완료 305/1000: 빅토리아 시크릿의 패키지는 언제나 고급스럽고 세련된 디자인으로 눈길을 끌어요.
# 생성 완료 306/1000: 요즘 #쏘피 생리대 패키지도 다양해서 선택의 폭이 넓어요.
# 생성 완료 307/1000: 요즘은 제이팜스의 스킨케어 세트가 가격대비 괜찮다는 소문이 있던데, 패키지 디자인도 무난한 편이에요.
# 생성 완료 308/1000: 아이소이의 제품은 사용하기는 편리하지만 가격대가 높아서 고민이 되네요.
# 생성 완료 309/1000: 최근에 구매한 #무로 프리미엄 베개 세트는 가격 대비 훌륭한 퀄리티를 자랑해요.
# 생성 완료 310/1000: "아이엠그루트라는 브랜드의 신제품이 정말 다양한 옵션을 제공해서 골라 사용하는 재미가 있네요."
# 생성 완료 311/1000: 최근에 구매한 마카롱샵의 패키지는 정말 다양해서 고르기가 어려웠어요.
# 생성 완료 312/1000: 새롭게 출시된 노스페이스의 재킷은 다양한 색상으로 선택의 폭이 넓어져서 마음에 들어요.
# 생성 완료 313/1000: 최근에 시도해 본 젤리케어의 스킨케어 패키지는 선택의 폭이 좁아서 아쉽네요.
# 생성 완료 314/1000: 키엘의 다양한 스킨케어 세트는 정말 많아서 선택하기 쉽지 않더군요.
# 생성 완료 315/1000: 갤러리아백화점에서 산 #플리츠마마 가방은 디자인이 참 세련되고 실용적이네요.
# 생성 완료 316/1000: 최근에 구매한 '무릉도원' 브랜딩의 선물 포장 박스는 너무 유명하지는 않지만, 디자인이 참 독특해서 한눈에 들어왔어요.
# 생성 완료 317/1000: "차앤박의 화장품 패키지는 깔끔한 디자인이지만, 가격이 비싸서 좀 아쉽네요."
# 생성 완료 318/1000: 요즘 핫한 #런드리랩 세탁세제, 가격대비 성능이 별로라서 실망했어요.
# 생성 완료 319/1000: "비비안의 신상 스타킹은 디자인이 세련됐지만, 가격이 너무 비싸네요."
# 생성 완료 320/1000: 요즘 SNS에서 핫한 '로이비' 화장품, 다양한 컬러 옵션 덕분에 선택의 폭이 넓어서 좋아요.
# 생성 완료 321/1000: 로이하우스의 다양한 색상과 스타일로 구성된 패키지는 내 취향 저격이었지만 가격대가 꽤 높아서 망설여졌어요.
# 생성 완료 322/1000: 이니스프리의 다양한 스킨케어 패키지는 선택의 폭이 넓어 좋지만, 가격은 조금 비싼 편이에요.
# 생성 완료 323/1000: 엄마가 추천해준 이 오설록 티 컬렉션, 종류가 너무 다양해서 매일 다른 맛을 즐길 수 있어요.
# 생성 완료 324/1000: 로이드의 시계는 디자인이 세련되었지만, 가격이 너무 비싸다는 생각이 들어요.
# 생성 완료 325/1000: 샤넬의 새로운 향수 패키지는 디자인도 세련되고 다양한 옵션이 있어 선택의 폭이 넓어 좋네요.
# 생성 완료 326/1000: 도프의 신제품 헤드셋은 가격은 좀 비싸지만 세련된 디자인이 마음에 들어요.
# 생성 완료 327/1000: 다이소에서 판매하는 다양한 디즈니 캐릭터 디자인의 노트들은 정말 저렴해서 학생들에게 인기가 많아요.
# 생성 완료 328/1000: 요즘 핫한 브랜딩랩의 패키지는 깔끔하고 세련된 디자인으로 누구나 탐낼 만한 매력이 있어요.
# 생성 완료 329/1000: 요즘 미니소의 브랜드 인지도가 많이 올라서 친구들이 다 알더라고요.
# 생성 완료 330/1000: "다이소의 패키지 디자인은 예쁘긴 하지만 너무 심플해서 아무런 특별함이 느껴지지 않아요."
# 생성 완료 331/1000: 최근 구매한 스타벅스 머그컵의 디자인이 너무 평범해서 실망했습니다.
# 생성 완료 332/1000: 그레고리 가방의 다양한 디자인은 여행할 때마다 감탄을 자아내요.
# 생성 완료 333/1000: 이번에 출시된 #위니아 에어컨은 다양한 옵션이 있어서 선택의 폭이 넓어서 좋았어요.
# 생성 완료 334/1000: 다이소의 다양한 포장 옵션은 언제나 내 선택을 폭넓게 해주네요.
# 생성 완료 335/1000: 오리온의 다양한 스낵 종류는 선택의 폭이 넓어서 좋아요.
# 생성 완료 336/1000: 요즘 인기가 많다는 루즈리프 브랜드 디노트는 디자인이 정말 세련됐어요.
# 생성 완료 337/1000: 여러 종류의 귤 감귤이 들어있는 자연드림의 패키지는 선택의 폭이 넓다고 생각돼요.
# 생성 완료 338/1000: 매일유업 음료의 패키지는 다양성이 부족해서 선택의 폭이 좁은 느낌이에요.
# 생성 완료 339/1000: 카이코스의 패키지는 사용하기 편리하게 잘 구성되어 있어서 정말 만족스럽습니다.
# 생성 완료 340/1000: 최근에 산 샤오미 전기포트는 가격 대비 성능이 우수해서 만족스러웠는데, 패키지는 그냥 보통이었어요.
# 생성 완료 341/1000: "토리든의 아이크림 제품은 가격대가 다소 높다고 느껴지지만, 패키지 디자인이 심플하고 세련되어 선물용으로도 인기가 많다."
# 생성 완료 342/1000: 최근에 접한 티테라의 다양한 향수 구성은 정말 매력적이었어요. 선택의 폭이 넓어서 기분에 따라 바꿔 쓰기 좋네요!
# 생성 완료 343/1000: 스카니아 트럭의 인지도가 높지만 디자인은 조금 구식이에요.
# 생성 완료 344/1000: "요즘 들어 마이프로틴의 가격이 너무 올랐다고 느끼는데, 품질 대비 가성비가 아쉽습니다."
# 생성 완료 345/1000: 레고 스타워즈 세트의 가격은 솔직히 너무 비싸지만 팬들에게는 그만큼 가치가 있다고 느껴져요.
# 생성 완료 346/1000: 최근에 알게 된 마텍사의 가전제품은 가격 대비 성능이 정말 만족스럽네요. 하지만 다양한 옵션이 부족한 건 아쉬웠어요.
# 생성 완료 347/1000: 쿠팡에서 샀던 마이비 포장 디자인은 정말 별로였습니다. 너무 심심하고 매력이 없네요.
# 생성 완료 348/1000: 스웨덴 브랜드 이케아의 가구는 가격은 저렴하지만 디자인은 언제나 예쁘고 실용적입니다.
# 생성 완료 349/1000: 젝시오의 골프채 세트는 디자인이 세련되어 보여서 필드에 나갈 때마다 눈길을 사로잡아요.
# 생성 완료 350/1000: 미코리디 티백 세트는 다양한 종류의 차를 한 번에 즐길 수 있어서 만족스러워요.
# 생성 완료 351/1000: 요즘 버츠비의 다양한 립밤 컬렉션이 나온 덕에 선택의 폭이 넓어졌네요.
# 생성 완료 352/1000: 최근에 구매한 마샤마일로의 패키지가 너무 예쁘다고 생각했는데, 가격이 꽤 비싸서 고민이 됐어요.
# 생성 완료 353/1000: 아이코스는 종류가 다양해서 선택의 폭이 넓고 편리하게 사용할 수 있어요.
# 생성 완료 354/1000: 최근에 출시된 '아이엠백'의 가방은 다양한 색상 선택이 가능해서 좋았어요.
# 생성 완료 355/1000: 최근에 구입한 마크앤로나 골프채 세트의 디자인이 너무 세련되게 잘 나왔어요!
# 생성 완료 356/1000: 레고는 다양한 테마와 세트가 있어 모든 연령대에게 맞춤형으로 선택할 수 있어서 좋습니다.
# 생성 완료 357/1000: 요즘 이니스프리의 패키지가 여러 가지로 출시되어 선택의 폭이 넓어졌어요.
# 생성 완료 358/1000: 드디어 파타고니아에서 출시한 다양한 레인재킷을 구매했는데, 가격이 너무 비싸서 조금 실망했어요.
# 생성 완료 359/1000: 실망스럽게도 비싸기만 한 엘지 냉장고의 부가 구성품들 때문에 고민 중이에요.
# 생성 완료 360/1000: 요즘 카페 노르디스크는 감각적인 디자인과 다양한 메뉴로 점점 인기를 얻고 있어요.
# 생성 완료 361/1000: 다이소의 상품들은 가격이 저렴하지만 품질은 그대로라 가성비가 좋습니다.
# 생성 완료 362/1000: 애플 제품은 디자인 면에서는 정말 최고지만, 가격은 매번 부담스러워요.
# 생성 완료 363/1000: 오랜만에 구입한 #마켓컬리의 식료품 패키지마저도 다양한 옵션을 제공해서 선택의 폭이 넓어 좋았어요!
# 생성 완료 364/1000: 어반디카이의 눈 화장품은 색상이 다양해서 선택의 폭이 넓어요.
# 생성 완료 365/1000: 브룩스 러닝화는 다양한 컬러와 스타일로 선택의 폭이 넓어서 좋아요.
# 생성 완료 366/1000: 최근에 구매한 바이레도의 핸드크림은 가격이 조금 비싸지만 디자인이 정말 매력적이네요.
# 생성 완료 367/1000: '캠핑아울렛의 텐트 패키지는 디자인이 세련되었지만 가격이 너무 높아요.'
# 생성 완료 368/1000: 리빙턴의 다채로운 색상과 스타일의 패키지는 선택의 폭이 넓어 정말 만족스러워요.
# 생성 완료 369/1000: 앤버추얼의 다양한 스킨케어 제품들이 최근 뷰티 트렌드에 맞춰 제대로 구성되어 있어서 선택의 폭이 넓어요.
# 생성 완료 370/1000: 키친아트의 주방용품은 디자인이 좀 평범하고 인지도도 낮은 편이라 아쉽네요.
# 생성 완료 371/1000: 고양이 장난감으로 유명한 '페토이'에서 나온 제품은 종류가 다양해서 선택의 폭이 넓어요.
# 생성 완료 372/1000: 이케아 가구는 디자인이 참 독특하고 매력적이지만, 조립이 복잡해서 불편할 때가 많아요.
# 생성 완료 373/1000: 가성비가 뛰어난 필웰의 다양한 사무용 가구는 가격 대비 품질이 정말 좋네요.
# 생성 완료 374/1000: 다양한 옵션을 제공하는 클라비스 노트북, 다양한 요구를 충족하는데 최적이에요.
# 생성 완료 375/1000: 최근에 구매한 파리바게뜨의 케이크 패키지는 디자인이 너무 평범해서 아쉬웠어요.
# 생성 완료 376/1000: 비타민하우스의 보충제 패키지는 너무 다양한데, 오히려 선택하기 어려워요.
# 생성 완료 377/1000: 가비아의 다양한 웹호스팅 옵션 덕분에 선택의 폭이 넓어졌어요.
# 생성 완료 378/1000: 최근 구매한 초코배낭의 디자인이 정말 마음에 들어요. 색상도 세련되고 패턴도 독특해서 친구들이 계속 물어봐요!
# 생성 완료 379/1000: 세련된 디자인의 탑텐 패션 패키지는 종류가 다양해서 선택의 폭이 넓어요.
# 생성 완료 380/1000: 최근에 구매한 피크닉의 다양한 컬러 옵션은 정말 매력적이에요, 하지만 가격은 조금 부담스럽네요.
# 생성 완료 381/1000: 오랄비 전동칫솔의 가격이 예전보다 많이 올랐던데, 가성비가 점점 떨어지는 것 같아요.
# 생성 완료 382/1000: 로보락의 진공청소기는 디자인이 모던해서 인테리어와도 잘 어울리네요.
# 생성 완료 383/1000: 최근 구매한 #에블린의 헤어 엘라스틱 세트는 패키지가 독특하고 사용하기 편리해요.
# 생성 완료 384/1000: 트루베의 스킨케어 키트는 옵션이 다양해서 필요에 따라 선택할 수 있어요.
# 생성 완료 385/1000: 요즘 들어 본 #모멘토의 패키지가 그렇게 편리하다는 이야기를 많이 듣네요.
# 생성 완료 386/1000: 에스프레소머신은 #드롱기 제품이 유명하지만, 다양한 옵션이 적어 아쉬워요.
# 생성 완료 387/1000: 최근에 구매한 레고의 패키지가 너무 예뻐서 선물용으로도 손색없어요.
# 생성 완료 388/1000: 친구가 추천해준 클라뷰 스킨케어 제품 패키지가 너무 예쁘고, 구성도 다양해서 선택하기 쉬웠어요.
# 생성 완료 389/1000: 인스타그램에서 보니까 마마무치킨의 다양한 소스는 유명한데, 가격이 조금 부담스럽더라고요.
# 생성 완료 390/1000: 크리니크의 패키지가 다양한 옵션을 제공해서 선택의 폭이 넓어요.
# 생성 완료 391/1000: "로프트랩의 다양한 컬러 옵션은 정말 매력적이지만 가격이 살짝 부담스럽네요."
# 생성 완료 392/1000: 최근에 구입한 타미힐피거 옷들의 디자인이 별로라서 실망했어요.
# 생성 완료 393/1000: 빅토리녹스의 다양한 칼 종류가 있어 선택의 폭이 넓습니다.
# 생성 완료 394/1000: 캘러웨이의 골프채 패키지는 가격이 꽤 부담스럽지만 다양한 옵션이 있어요.
# 생성 완료 395/1000: "외관이 너무 세련된 미니랩은 패키지부터 디자인이 상당히 매력적이네요."
# 생성 완료 396/1000: 레스포색의 가방은 다양한 디자인과 색상으로 선택의 폭이 넓어서 좋아요.
# 생성 완료 397/1000: 오랜만에 구입한 조말론 향수, 독특한 패키지 디자인이 매력적이에요.
# 생성 완료 398/1000: 비싸기만 한 #마샬 스피커보다는 다양한 기능이 있는 점프오디오가 더 나은 선택이었어요.
# 생성 완료 399/1000: 프렌치키친의 조리도구 세트는 가격 대비 종류가 너무 부족한 것 같아요.
# 생성 완료 400/1000: 최근에 구입한 데코뷰의 커튼은 디자인이 예쁘긴 한데 가격이 너무 비싸서 살짝 아쉽습니다.
# 생성 완료 401/1000: 최근에 구입한 #아비노의 보습 크림은 가격이 좀 비싸서 부담스럽네요.
# 생성 완료 402/1000: 저는 #로이체 이어폰을 좋아하는데, 디자인도 참신하고 가격도 괜찮아요.
# 생성 완료 403/1000: 나는 주식회사 요이코의 스테이셔너리 세트가 유명하지 않아서 고를 때 망설였다.
# 생성 완료 404/1000: 스타벅스의 시그니처 텀블러는 디자인 면에서는 감각적이지만, 가격은 조금 부담스럽네요.
# 생성 완료 405/1000: 빌리프의 스킨케어 세트는 가격대가 조금 있지만, 다양한 제품 구성이 매력적이에요.
# 생성 완료 406/1000: 다양한 옵션이 있어 선택할 수 있는 아우디의 자동차 액세서리 라인은 매우 만족스럽습니다.
# 생성 완료 407/1000: 새로 나온 네오플램의 주방 용품은 다양한 색상과 디자인으로 주방을 화사하게 해줘요.
# 생성 완료 408/1000: 제가 사용한 루이까또즈의 가방은 다양한 색상과 디자인으로 유명하지만, 가격은 다소 부담스러워요.
# 생성 완료 409/1000: 다이소의 다양한 문구 세트는 가격 대비 가성비가 낮은 것 같아요.
# 생성 완료 410/1000: 최근에 구매한 지샥 시계가 생각보다 다양한 색상과 디자인으로 이목을 끌어요.
# 생성 완료 411/1000: 최근에 나온 콜맨 텐트는 가격은 비싸지만 캠핑 용품 중에서는 디자인이 제일 마음에 들어요.
# 생성 완료 412/1000: 최근에 알게 된 클래식한 디자인의 윌리엄스 소노마 주방용품은 유명세가 부족하지만, 사용하기에 아주 간편해요.
# 생성 완료 413/1000: 샤오미 스마트워치의 다양한 스트랩 옵션 덕분에 매일 다른 스타일을 연출할 수 있어요!
# 생성 완료 414/1000: 최근에 구입한 비비고의 다양한 만두 패키지는 종류가 많아서 가족들의 취향을 골고루 만족시킬 수 있어요.
# 생성 완료 415/1000: 프랑스 브랜드 라로슈포제의 스킨케어 라인은 가격이 꽤나 높지만, 그만큼 품질은 확실히 뛰어나네요.
# 생성 완료 416/1000: 오랜만에 사본 브릭스톤 모자, 디자인은 이쁜데 가격이 생각보다 꽤 비싸네요.
# 생성 완료 417/1000: 최근에 구입한 아디다스의 운동화는 다양한 색상이 있어 선택의 폭이 넓더라고요.
# 생성 완료 418/1000: 오랜만에 타라시코 가방을 샀는데, 디자인은 예쁜데 가격이 좀 비싼 것 같아요.
# 생성 완료 419/1000: 레노버의 최근 노트북은 스펙은 좋은데, 옵션의 다양성이 조금 아쉬워요.
# 생성 완료 420/1000: 요즘 마이보틀 브랜드의 디자인이 독특해서 사용하는 사람들을 많이 보게 되네요.
# 생성 완료 421/1000: 헤라의 립스틱이 참 예쁘지만, 색상 선택의 폭이 조금 아쉬워요.
# 생성 완료 422/1000: 리처드밀 시계는 디자인만큼이나 브랜드 인지도도 상당히 높습니다.
# 생성 완료 423/1000: 최근에 아토팜의 다양한 스킨케어 제품을 써봤는데, 종류도 많고 선택의 폭이 넓어서 너무 좋았어요.
# 생성 완료 424/1000: 요즘 자주 보이는 브랜드인 '슈밀리'의 가격이 좀 비싼 편이라 망설여져요.
# 생성 완료 425/1000: 스튜디오 톰보이의 신제품 옷걸이 세트는 가격 대비 종류가 너무 제한적이네요.
# 생성 완료 426/1000: 최근에 구매한 르이트의 헤드폰은 다양한 색상 옵션이 있어서 고르는 재미가 있더라구요.
# 생성 완료 427/1000: "요즘 인기 있는 브랜드인 이케아의 다양한 가구들은 저렴한 가격대 덕분에 많은 소비자들에게 인기를 끌고 있어요."
# 생성 완료 428/1000: 큐리오스의 다양한 커피머신 옵션은 선택의 폭이 넓어 만족스러웠어요.
# 생성 완료 429/1000: 오토엔의 차량용 방향제는 디자인이 참 세련되었지만, 가격이 꽤 비싸서 망설여지네요.
# 생성 완료 430/1000: "이케아의 패키징은 심플하지만, 조립 설명서가 너무 복잡해서 이해하기 어려웠어요."
# 생성 완료 431/1000: 최근 구매한 마마스앤파파스 유모차의 디자인이 너무 세련되어서 외출할 때마다 눈에 띄네요.
# 생성 완료 432/1000: 최근에 구매한 마티나 골드의 커피머신 패키지는 너무 평범해서 실망했어요.
# 생성 완료 433/1000: 칼라스의 신제품 냄비세트는 디자인도 세련되고 다양한 옵션이 있어 주방 분위기에 맞게 선택할 수 있어요.
# 생성 완료 434/1000: 밴드에이드의 가격이 너무 비싸서 사용하는데 부담되네요.
# 생성 완료 435/1000: 제누스는 브랜드 인지도는 높지 않지만, 가성비가 뛰어난 제품으로 평가되고 있어요.
# 생성 완료 436/1000: 요즘 스포티지의 인기는 정말 대단하지만, 개인적으로는 가격이 조금 비싼 느낌이 있어요.
# 생성 완료 437/1000: 최근에 구매한 나뚜루 아이스크림의 패키지는 너무 단조로워서 좀 실망스럽네요.
# 생성 완료 438/1000: 프릴의 세제는 가격이 다른 브랜드보다 비싼 편이지만, 사용 편의성은 정말 뛰어나요.
# 생성 완료 439/1000: 미쟝센 헤어팩은 다양한 옵션이 많아서 머리 상태에 맞게 선택할 수 있어요.
# 생성 완료 440/1000: 아쌤의 포장 재질은 튼튼하긴 한데, 디자인이 너무 올드하네요.
# 생성 완료 441/1000: 최근에 출시된 이케아의 가구 패키지는 가격 대비 구성품의 다양성이 부족한 것 같아요.
# 생성 완료 442/1000: 최근에 사용해본 LG전자의 다양한 가전제품들, 특히나 그 디자인이 마음에 들었어요. 어디에 두어도 잘 어울리고, 확실히 고급스러워보여요.
# 생성 완료 443/1000: 시세이도 화장품의 패키지가 너무 고급스러워서 선물용으로 딱이에요!
# 생성 완료 444/1000: 최근에 구매한 파버카스텔의 색연필세트는 색상이 다양해서 그림 그릴 때 너무 좋았어요.
# 생성 완료 445/1000: 리바이스 지갑은 가격 대비 디자인이 별로여서 실망했어요.
# 생성 완료 446/1000: 비트바이츠의 패키지는 다양한 구성품덕에 고객마다 선택의 폭이 넓어서 마음에 들어요.
# 생성 완료 447/1000: 최근에 구매한 내셔널지오그래픽 백팩은 다양한 수납공간 덕분에 정말 편리하네요.
# 생성 완료 448/1000: 여러 종류의 색상을 제공하는 마르헨제이의 가방은 선택의 폭이 정말 넓어서 좋아요.
# 생성 완료 449/1000: 오랜만에 우연히 접한 #비스포크 아이템은 디자인이 세련돼서 마음에 쏙 들었어요.
# 생성 완료 450/1000: 캔메이크의 화장품은 저렴한 가격과 다양한 선택지가 정말 마음에 듭니다.
# 생성 완료 451/1000: 요즘 CM2의 패키지가 참 소문난 만큼 예쁘다고 하더라구요, 그래서 저도 하나 샀습니다.
# 생성 완료 452/1000: 이번에 새로 나온 리바이스 청바지 패키지, 종류가 다양해서 선택의 폭이 넓어요.
# 생성 완료 453/1000: 최근에 구입한 올리브영의 헤라 화장품 패키지는 디자인이 너무 평범해서 좀 아쉽더라고요.
# 생성 완료 454/1000: "데드씨 미네랄스의 스킨케어 제품은 패키지 디자인이 고급스러워 보이긴 하지만 가격이 다소 비싸게 느껴지네요."
# 생성 완료 455/1000: 도큐먼트스튜디오라는 브랜드는 아직 많이 알려지지 않았지만, 사용하기에 매우 편리한 다양한 옵션을 제공합니다.
# 생성 완료 456/1000: 블랭크퍼센트의 패키지 디자인은 너무 세련되고 고급스러워서 보는 사람마다 칭찬이 쏟아져요.
# 생성 완료 457/1000: 케이스티파이의 휴대폰 케이스는 다양한 디자인과 높은 인지도로 유명하지만, 가격이 좀 비싼 편이에요.
# 생성 완료 458/1000: 뉴발란스의 다양한 운동화 옵션으로 선택의 폭이 넓어져서 너무 좋아요!
# 생성 완료 459/1000: 최근에 구입한 베베가닉 기저귀는 패키지 디자인이 너무 단조롭고 밋밋해서 실망했어요.
# 생성 완료 460/1000: 타미힐피거의 옷들은 디자인은 좋지만, 가격이 비싼 편이라 가성비 측면에서는 부담스러워요.
# 생성 완료 461/1000: 미니소의 휴대폰 케이스는 예쁜 디자인에 비해 가격이 조금 비싼 편이에요.
# 생성 완료 462/1000: 최근에 출시된 #이케아 가구는 디자인이 참 깔끔하고 모던한데, 가격은 꽤나 높게 책정된 것 같아요.
# 생성 완료 463/1000: 에코버 세제의 다양한 향은 선택의 폭을 넓혀줘서 좋지만, 가격이 다소 비싸다고 느껴지네요.
# 생성 완료 464/1000: 무인양품의 패키지는 깔끔하지만 가격이 비싸서 아쉽네요.
# 생성 완료 465/1000: 얼리어답터들 사이에서 인기를 끌고 있는 나노테크의 최신 스마트폰은 다양한 액세서리 옵션이 있지만 가격은 다소 비싼 편이다.
# 생성 완료 466/1000: 조이라이드의 신발 패키지는 다양하게 선택할 수 있는 옵션이 많아서 정말 좋아요.
# 생성 완료 467/1000: 최근에 다이소에서 다양한 옵션의 포장재를 발견했는데, 특별히 인상적이지 않았어요.
# 생성 완료 468/1000: 로레알의 스킨케어 제품은 종류가 다양해서 피부 타입에 맞는 선택이 가능해요.
# 생성 완료 469/1000: 송월타월의 다양한 패키지가 정말 마음에 드네요, 선물용으로 딱이예요!
# 생성 완료 470/1000: 오랜만에 나온 코델리아 화장품의 신제품 패키지, 디자인은 깔끔하지만 특별한 감흥은 없네요.
# 생성 완료 471/1000: 요즘 많이들 사용하는 아토팜의 제품은 괜찮은데, 패키지 디자인이 조금 지루해요.
# 생성 완료 472/1000: 최근에 구매한 #지오다노 셔츠의 디자인은 기본적이지만 깔끔해서 실망하지 않았어요.
# 생성 완료 473/1000: 소니의 헤드폰은 디자인이 세련되었지만 가격이 너무 부담스러워요.
# 생성 완료 474/1000: 요즘 TV에서 광고를 자주 보는 나이키의 이번 컬렉션은 디자인이 좀 밋밋해서 실망스러웠어요.
# 생성 완료 475/1000: 로레알의 다양한 색상 옵션은 나에게 항상 선택의 폭을 넓혀줍니다.
# 생성 완료 476/1000: 요즘 꽤 유명한 울리치 패딩이긴 하지만 가격이 너무 높아서 부담스럽습니다.
# 생성 완료 477/1000: 화려한 디자인으로 유명한 #이케아 가구는 여러 옵션이 있어서 고르기가 어렵더라고요.
# 생성 완료 478/1000: 아웃도어 브랜드인 슬래즈엔클럽의 제품은 다양한 색상과 디자인으로 선택의 폭이 넓어 사용하기 편리하네요.
# 생성 완료 479/1000: 애플의 최신 아이패드 케이스는 디자인은 세련되었지만 가격이 너무 부담스럽네요.
# 생성 완료 480/1000: 글로우픽에서 추천받은 이네이처의 신제품 포장 디자인은 정말 예쁘긴 한데, 다양성 측면에서는 조금 아쉬워요.
# 생성 완료 481/1000: 덴티스테 치약은 다양한 종류가 있어서 선택의 폭이 넓다는 점이 마음에 들어요.
# 생성 완료 482/1000: 요즘 SNS에서 핫한 '익스스템'의 포장재는 디자인도 깔끔하고 환경에 미치는 영향을 줄여줘서 마음에 듭니다.
# 생성 완료 483/1000: 최근에 써본 #네오플램 프라이팬은 가격도 적당하고 손잡이 디자인도 세련돼서 마음에 쏙 들어요!
# 생성 완료 484/1000: "이노마타의 주방 용품은 다양한 색상과 용량으로 선택의 폭이 넓어 주부들에게 인기가 많습니다."
# 생성 완료 485/1000: 다양한 색상의 립스틱을 제공하는 3CE, 가격은 조금 비싸지만 색상 선택의 폭이 넓어서 만족해요.
# 생성 완료 486/1000: 아스트로의 패키지는 디자인이 너무나 평범해서 시선을 끌지 못하네요.
# 생성 완료 487/1000: 아이허브에서 구매한 블랙21 가방은 디자인이 심플하면서도 세련된 느낌이라 출근할 때 딱이에요.
# 생성 완료 488/1000: 빌리프의 스킨케어 세트는 다양한 종류로 골라 쓸 수 있어요.
# 생성 완료 489/1000: 최근에 사용해 본 레브론의 마스카라는 정말 다양한 색상 옵션이 있었어요.
# 생성 완료 490/1000: 비록 모나미의 인기도는 예전같지 않지만, 그들의 다양한 색상 옵션은 언제나 매력적이네요.
# 생성 완료 491/1000: 최근에 구매한 블루투스 스피커가 들어있는 소니 패키지의 디자인이 너무 세련되었어요.
# 생성 완료 492/1000: 이케아의 패키지 구성은 다양한 선택지가 있어 이사할 때 매우 유용하네요.
# 생성 완료 493/1000: 요즘 이케아의 가구 디자인이 심플하고 세련되면서도 가격은 정말 합리적인 것 같아요.
# 생성 완료 494/1000: 스위스 미스의 초콜릿 맛 핫코코아는 다양한 맛 옵션이 없어서 아쉬웠어요.
# 생성 완료 495/1000: 요즘 한샘의 가구 디자인이 정말 매력적이라, 집 안 분위기를 확 바꿔줍니다.
# 생성 완료 496/1000: 퀴니의 유모차 디자인은 정말 세련되었지만 좀 비싼 게 흠이에요.
# 생성 완료 497/1000: 너무 저렴해 보이는 포장 때문에 케이스 대신 쓰기 꺼려지는 #더블에이 패키지.
# 생성 완료 498/1000: 최근에 구입한 샤넬의 새로운 향수 패키지는 기대 이상으로 세련된 디자인이어서 선물용으로도 제격이었어요.
# 생성 완료 499/1000: 나의 새로 산 다이소의 필기구 세트는 가격은 저렴하지만 정말 다양한 종류가 있어서 고르기가 힘들 정도였어요.
# 생성 완료 500/1000: 리코의 최신 카메라 스트랩은 다양한 색상과 패턴 덕분에 어떤 스타일에도 잘 어울립니다.
# 생성 완료 501/1000: 최근에 구입한 로라메르시에 제품은 가격이 좀 비싸지만 유명세가 있어서 구매했어요.
# 생성 완료 502/1000: 코카콜라의 다양한 패키지 디자인 덕분에 파티 분위기가 한층 살아났어요!
# 생성 완료 503/1000: 아이돌레 커피머신의 다양한 색상은 주방 인테리어를 한층 더 돋보이게 해줍니다.
# 생성 완료 504/1000: 최근에 구매한 루이까또즈 지갑은 디자인이 참 고급스러워요, 그런데 가격이 생각보다 좀 부담스러웠어요.
# 생성 완료 505/1000: #핑크후르츠의 향이 은은하게 나는 티트리 수딩 패드, 디자인적으로도 깔끔하고 마음에 쏙 들어요.
# 생성 완료 506/1000: 최근에 구매한 팔레트 액세서리의 가성비가 좋지 않아서 실망스럽네요.
# 생성 완료 507/1000: 이번에 새로 출시된 아카데미 과학의 나노블록 시리즈는 종류가 다양해서 구성하기가 재미있어요!
# 생성 완료 508/1000: 최근에 구입한 오리온 스낵팩의 다양한 맛이 가방에 쏙 들어가서 어디든지 간편하게 챙겨 다닐 수 있어요.
# 생성 완료 509/1000: 최근에 구매한 '인퍼가젯' 이어폰은 가격대비 옵션이 다양해서 좋았어요! 🎧
# 생성 완료 510/1000: 라무리케어의 새로운 스킨케어 라인은 디자인이 너무 평범해서 아쉬웠어요.
# 생성 완료 511/1000: 최근에 구입한 카페24의 텀블러는 디자인이 과하게 화려하지 않고 딱 적당해서 좋았어요.
# 생성 완료 512/1000: 파운데이션은 #에뛰드하우스 것이 디자인이 예쁜데, 가격이 좀 비싼 편이에요.
# 생성 완료 513/1000: 요즘 제우스랩의 외장하드를 사용하는데, 가격이 생각보다 비싸서 가성비가 아쉽네요.
# 생성 완료 514/1000: 요즘 패션 업계에서 많이 보이는 잇미샤의 신상 디자인은 세련됨으로 가득 찬 느낌이지만, 가격대가 고민되네요.
# 생성 완료 515/1000: 요즘 핫한 코렐의 식기세트는 디자인은 예쁜데 가격이 좀 부담스럽네요.
# 생성 완료 516/1000: 올리브영에서 판매하는 '하루에비타민'의 다양한 옵션은 소비자에게 좋은 선택지를 제공합니다.
# 생성 완료 517/1000: 국내에서는 다소 생소하지만 캔노스의 가죽 커버 패키지는 평범한 디자인이 아쉽네요.
# 생성 완료 518/1000: 최근에 구입한 온더바디 바디워시 세트는 가격이 좀 있는 편이라 부담스럽네요.
# 생성 완료 519/1000: 마이리틀타이거 장난감의 패키지는 너무 단순해서 실망스러웠어요.
# 생성 완료 520/1000: 헤어를 부드럽게 만들어 주는 아베다의 컨디셔너는 가격이 좀 비싸지만, 그만큼 가치가 있는 것 같아요.
# 생성 완료 521/1000: 최근에 구입한 오리젠 반려동물 사료는 가격이 조금 비싸지만, 다양한 맛의 조합이 있어 우리 반려견이 질리지 않아요.
# 생성 완료 522/1000: 종근당건강의 유산균 패키지는 다양한 선택지가 있어 소비자 입장에서 참 좋습니다.
# 생성 완료 523/1000: 샤넬의 향수 디자인은 확실히 고급스럽고 시각적으로 매력적이지만, 가격은 꽤 부담스럽네요.
# 생성 완료 524/1000: 르누블의 향수 세트는 디자인이 참신해서 방에 두기만 해도 장식품 같아요.
# 생성 완료 525/1000: 코코도르의 다양한 향초 옵션은 정말 특별하지만 가격이 조금 비싼 것 같아요.
# 생성 완료 526/1000: 패션 브랜드 '이온즈'의 가격은 타 브랜드에 비해 상당히 합리적으로 느껴지네요.
# 생성 완료 527/1000: 리파의 다양한 스킨케어 제품들은 정말 선택의 폭이 넓어서 만족스러워요.
# 생성 완료 528/1000: 에코백의 디자인은 마음에 드는데, 가격이 너무 비싸요.
# 생성 완료 529/1000: 최근에 구매한 조셉조셉의 주방 도구 세트는 너무 비싸서 당황스러웠어요.
# 생성 완료 530/1000: 요즘 #레노버 노트북의 인기가 떨어졌다는 얘기가 많이 들리네요, 가격 대비 성능이 좀 떨어지는 듯해요.
# 생성 완료 531/1000: 최근에 알게 된 브랜드인 #라발린의 다양한 헤어케어 옵션은 선택의 폭이 넓어 좋지만, 가격대가 살짝 아쉽네요.
# 생성 완료 532/1000: 브리타의 필터 교체 주기가 짧아 자주 비용이 많이 들어가네요.
# 생성 완료 533/1000: 최근 소문난 리베리오 전자레인지, 디자인이 심플하고 부엌 인테리어와 잘 어울려서 마음에 들어요.
# 생성 완료 534/1000: 이케아는 디자인이 심플하지만 고급스러운 느낌을 주며, 가구 조립이 생각보다 간편해서 좋아요.
# 생성 완료 535/1000: 여러 종류의 향수를 살펴보던 중, 조말론은 다양한 향을 제공하지만 가격은 조금 비싼 편이에요.
# 생성 완료 536/1000: 밤톨의 식품 브랜드는 비싼 것 같지만, 그만큼 품질이 좋다고들 하더라고요.
# 생성 완료 537/1000: 리바트 가구는 디자인이 무난하고 가격도 합리적이라 많은 사람들이 선호하죠.
# 생성 완료 538/1000: 페리페라의 가격은 저렴하긴 한데, 색상 종류가 너무 한정적이라 아쉬워요.
# 생성 완료 539/1000: 최근에 구입한 발뮤다 토스터기의 가격은 조금 부담스럽지만, 디자인만큼은 정말 예술이네요.
# 생성 완료 540/1000: 이번에 구매한 에코파르크 주스의 패키지는 화려한 색상 덕분에 냉장고 안에서도 눈에 잘 띄어요.
# 생성 완료 541/1000: 최근에 구입한 요가매트가 아디다스 브랜드인데, 가격 대비 품질이 뛰어난 것 같아요.
# 생성 완료 542/1000: #Hario의 커피 드리퍼가 유명하긴 하지만, 개인적으로는 비슷한 가격대에서는 #Kalita의 다양성이 더 마음에 듭니다.
# 생성 완료 543/1000: 반스 슬립온은 다양한 컬러와 패턴이 있어서 매일 다른 스타일로 연출할 수 있어요.
# 생성 완료 544/1000: 유명한 브랜드는 아니지만 모드락의 패키지 디자인은 심플하고 깔끔해서 마음에 들어요.
# 생성 완료 545/1000: 최근에 구매한 라로슈포제의 선크림은 다양한 용량 옵션 덕분에 선택지가 넓어서 좋았어요.
# 생성 완료 546/1000: 최근에 구매한 아모레퍼시픽의 화장품 패키지는 깔끔하기는 한데, 디자인이 조금 밋밋하네요.
# 생성 완료 547/1000: 최근에 구입한 #스킨푸드의 패키지가 너무 복잡해서 다루기 힘들어요.
# 생성 완료 548/1000: 주방용품 브랜드로는 덜 알려진 제니홈의 포장 디자인이 정말 세련되었어요.
# 생성 완료 549/1000: 에스쁘아의 립스틱은 가격대가 조금 높지만, 독특한 색상과 디자인으로 많은 사람들에게 인기가 많아요.
# 생성 완료 550/1000: 가성비가 뛰어난 것으로 소문난 #참존의 페이스팩은 종류도 다양하고 여러 선택지가 있어 좋아요.
# 생성 완료 551/1000: 최근에 구매한 #탠디 핸드백은 디자인이 고급스러워서 정말 마음에 들어요.
# 생성 완료 552/1000: 최근에 구매한 노르디스크 텐트의 디자인은 정말 예쁘지만, 가격이 너무 비싸서 좀 아쉬워요.
# 생성 완료 553/1000: 이번에 사온 로레알 샴푸는 디자인이 참 세련된 느낌이라 욕실에 놓기에도 좋아요.
# 생성 완료 554/1000: 독특한 디자인의 아이스크리트 플레이스테이션 패키지가 구매욕을 자극했지만, 가격이 너무 비싸서 고민이에요.
# 생성 완료 555/1000: 스타벅스의 다양한 음료 옵션이 많이 있지만, 가격은 조금 비싼 편이라 아쉬워요.
# 생성 완료 556/1000: 새로 나온 아이리버 이어폰은 가격대비 성능이 뛰어나지만, 디자인이 좀 아쉬워요.
# 생성 완료 557/1000: 최근에 구입한 무인양품의 스테인리스 수저 세트가 생각보다 저렴해서 가성비가 정말 좋네요.
# 생성 완료 558/1000: 최근에 알게 된 브랜드인 마르헨제이는 가방 디자인이 대체로 독특하면서도 심플해서 마음에 들었어요.
# 생성 완료 559/1000: 요즘 티르리르 주얼리가 디자인으로 유명한데, 특히 목걸이 패키지가 정말 고급스럽고 예뻐요.
# 생성 완료 560/1000: 캐리어의 디자인은 정말 깔끔해서 마치 갤러리의 작품을 보는 느낌이에요.
# 생성 완료 561/1000: Avidlove의 패션 제품은 디자인이 다양해서 선택의 폭이 넓지만, 가격은 다소 부담스럽네요.
# 생성 완료 562/1000: 최근에 산 샤오미 공기청정기, 디자인이 살짝 밋밋하긴 하지만 확실히 가성비는 좋네요.
# 생성 완료 563/1000: 비록 미샤 제품의 패키지는 고급스럽지 않지만, 가격 대비 효과가 좋아요.
# 생성 완료 564/1000: 모나미의 다양한 색상 볼펜 세트는 부담 없는 가격에 다양한 컬러를 골라 쓸 수 있어요.
# 생성 완료 565/1000: 인테리어를 고려한 #한샘의 다양한 가구 패키지가 마음에 들었지만, 가격이 꽤나 부담되네요.
# 생성 완료 566/1000: 요즘 핫한 브랜드인 로우로우의 가방은 디자인이 세련되어 시각적 매력이 뛰어나지만, 가격대가 높아 구매를 망설이게 됩니다.
# 생성 완료 567/1000: 세트 구성이 다양한 #허쉬 초콜릿 패키지는 선물하기에도 좋지만, 가격대가 조금 높아서 아쉬워요.
# 생성 완료 568/1000: 최근에 구매한 소다스트림의 다양한 음료 제조 옵션은 생각보다 훨씬 유용하네요.
# 생성 완료 569/1000: 팁토이조이의 신발은 디자인이 예쁘고 다양한 옵션도 제공해서 아이들 신기기 좋네요.
# 생성 완료 570/1000: 레드베리의 다양한 패키지는 고객의 선택의 폭을 넓혀줘서 좋습니다.
# 생성 완료 571/1000: 비록 만다리나덕 가방 브랜드의 가격이 다른 제품들에 비해 다소 높긴 하지만, 디자인만큼은 확실히 세련된 느낌이에요.
# 생성 완료 572/1000: 요즘 친구들이 다들 추천하는 라헬코스의 다양한 메이크업 브러쉬 세트는 종류가 많아서 선택의 폭이 넓어요.
# 생성 완료 573/1000: 스무디킹은 다양한 맛 옵션이 많아서 골라 먹는 재미가 있어요.
# 생성 완료 574/1000: 스누피 마스크팩은 종류가 다양해서 피부 타입에 맞춰 선택하기 좋아요.
# 생성 완료 575/1000: 이케아의 가구 디자인은 깔끔하지만 패키지 조립이 어렵고 설명서가 복잡한 편이에요.
# 생성 완료 576/1000: 최근에 알게 된 #코멧브랜드의 스킨케어 제품은 가격대가 꽤 저렴해서 부담 없이 구매할 수 있었어요.
# 생성 완료 577/1000: 최근에 구매한 업사이클드 브랜드 #알마시티의 가격대가 생각보다 합리적이라 놀랐어요!
# 생성 완료 578/1000: 옥수수 칩의 다양한 맛을 제공하는 도리토스는 언제 먹어도 질리지 않아요!
# 생성 완료 579/1000: 스위스 밀리터리 제품들은 디자인이 너무 단조롭네요. 색상도 다양하지 않아서 아쉽습니다.
# 생성 완료 580/1000: 롯데리아의 메뉴는 다양해서 선택하기가 즐거워요.
# 생성 완료 581/1000: 로마의 아르젠토 침대는 인지도는 높지 않지만, 가격 대비 성능이 괜찮아서 만족스러워요.
# 생성 완료 582/1000: 최근에 산 샤넬 향수의 패키지는 너무 세련돼서 시각적으로 정말 매력적인 것 같아요.
# 생성 완료 583/1000: 에르메스의 멋진 가방은 항상 사람들의 주목을 받지만, 지나치게 높은 가격이 아닌가 싶어요.
# 생성 완료 584/1000: 요즘 들어 다양한 디자인으로 인기를 끌고 있는 #노블레스 가방은 독특한 패턴과 색상 조합이 매력적이지만 가격이 조금 비싼 편이에요.
# 생성 완료 585/1000: 노트북 가방 구매했는데 소니의 디자인은 역시 세련되서 좋긴한데 조금 비싼 감이 있어요.
# 생성 완료 586/1000: 초콜릿 브랜드인 페레로로쉐는 가격이 비싸서 자주 사지는 않지만, 인지도는 매우 높아서 선물용으로 딱이에요.
# 생성 완료 587/1000: 요즘 에코백이 대세라고 하지만 스테디셀러인 #데일리라이트의 디자인은 너무 평범해서 감흥이 없어요.
# 생성 완료 588/1000: 저는 스튜디오드래곤의 드라마 한정판 굿즈가 너무 비싸서 아쉬웠어요.
# 생성 완료 589/1000: 최근에 사온 먼데이하우스의 다양한 가구들은 스타일도 좋고 집에 잘 어울려요.
# 생성 완료 590/1000: 최근에 구입한 로지텍 마우스는 다양한 색상 옵션이 있어서 선택에 고민이 좀 됐어요.
# 생성 완료 591/1000: 스타벅스의 다양한 텀블러 디자인은 정말 눈길을 사로잡아요.
# 생성 완료 592/1000: 코크렐 패키지는 너무 평범하고 눈에 띄지 않아서 조금 아쉽네요.
# 생성 완료 593/1000: 이 헤이즐넛 초코볼 세트는 패키지 디자인이 고급스럽고 매력적이라 선물용으로 좋습니다.
# 생성 완료 594/1000: 최근에 산 에르메스의 손수건 패키지는 디자인이 너무 고급스러워서 선물용으로 딱이에요.
# 생성 완료 595/1000: 로이히츠보코의 패치가 워낙 유명해서 구입했는데, 가격은 조금 높은 느낌이네요.
# 생성 완료 596/1000: 레고는 구성이 다양해서 아이들이 원하는 대로 조립할 수 있는 점이 참 좋더군요.
# 생성 완료 597/1000: AVAJU의 포장 디자인은 과하지 않으면서도 우아한 느낌을 주는 게 매력적이에요.
# 생성 완료 598/1000: 최근에 구매한 글램디의 주방용품 세트는 디자인은 참 예쁜데, 가격이 너무 부담스럽네요.
# 생성 완료 599/1000: 마르헨제이의 가방은 디자인이 참 세련됐고, 다양한 스타일로 선택할 수 있어 만족스럽네요.
# 생성 완료 600/1000: 최근에 구매한 웰넥스의 아로마 테라피 패키지가 너무 예쁘고 활용도가 높더라구요. 다만 가격이 조금 비싼 편이긴 해요.
# 생성 완료 601/1000: 진짜 이디야 커피의 패키지가 너무나 예쁘고 독창적이어서 매일 아침 기분이 좋습니다.
# 생성 완료 602/1000: 파버카스텔의 색연필 세트는 다양한 색상 옵션이 있어 선택의 폭이 넓어요. 다만 가격이 조금 비싼 편이라 고민되네요.
# 생성 완료 603/1000: 아임마크의 신발 패키지는 다양한 디자인과 색상으로 선택의 폭이 넓지만, 가격대가 조금 높은 편이에요.
# 생성 완료 604/1000: 요즘 클리오 화장품의 패키지 구성이 너무 단조로워서 실망이에요.
# 생성 완료 605/1000: 다이소의 제품은 가격이 저렴한데 패키지 디자인마저 심플하고 예뻐서 선물하기 딱 좋아요!
# 생성 완료 606/1000: 최근에 구매한 윌로우트리의 스킨케어 제품은 가격 대비 품질이 그다지 뛰어나지 않네요.
# 생성 완료 607/1000: 요즘 아르니카티 브랜드의 제품은 가격 대비 디자인이 뛰어나서 눈길을 끌어요.
# 생성 완료 608/1000: 최근에 구매한 삼성 노트북의 부가 패키지는 가격 대비 가성비가 아쉽네요.
# 생성 완료 609/1000: 코끼리 브로슈어의 휴대용 마우스는 가격이 저렴해서 부담 없이 구매할 수 있어요.
# 생성 완료 610/1000: 최근에 구입한 아이소이 스킨케어는 패키지 디자인이 너무 예뻐서 선물용으로도 좋겠더라구요.
# 생성 완료 611/1000: 안타깝게도 프리마클라셰의 디자인은 다른 브랜드에 비해 조금 촌스럽네요.
# 생성 완료 612/1000: 아르마니 향수는 가격이 꽤 높은 편인데도 불구하고, 그 패키지 디자인은 정말 매력적이에요.
# 생성 완료 613/1000: 최근에 산 엘파엠 브랜드의 무선 이어폰은 가격은 좀 비싸지만 디자인은 꽤 세련되어 보입니다.
# 생성 완료 614/1000: 최근 구매한 텀블러의 패키지 디자인이 은은한 컬러로 너무 예뻐서 매일 들고 다녀요.
# 생성 완료 615/1000: 화장품 브랜드 라운드랩은 디자인이 깔끔해서 마음에 들어요.
# 생성 완료 616/1000: 에어팟 프로의 편리한 연결성은 물론이고, 벨킨의 충전기까지 포함된 패키지가 정말 가치있다고 생각되네요.
# 생성 완료 617/1000: 피코크의 다양한 스낵 종류는 손님 맞이하기 좋더군요.
# 생성 완료 618/1000: 플랜트로닉스 헤드셋의 가격이 비싼지라 구매를 망설였지만, 다양한 기능들이 꽤 매력적이라 만족스럽습니다.
# 생성 완료 619/1000: LG의 가전제품들은 다양한 가격대와 옵션을 제공하여 소비자 선택의 폭을 넓혀줍니다.
# 생성 완료 620/1000: 캐리어에서 제공하는 사은품이 너무 다양해서 선택의 폭이 넓어요.
# 생성 완료 621/1000: "요즘 사람들이 차전자피로 잘 아는 정관장의 브랜드 파워는 정말 대단한 것 같아요."
# 생성 완료 622/1000: 최근에 구입한 벨킨 충전 케이블 세트는 가격은 조금 비싸지만 디자인이 정말 세련됐어요.
# 생성 완료 623/1000: 제이리틀의 포장지는 디자인이 참 독특해서 받는 순간 기분이 좋아요.
# 생성 완료 624/1000: 스탠리의 도시락은 디자인도 깔끔하고 내부 구성품도 다양해서 선택의 폭이 넓어요.
# 생성 완료 625/1000: 이케아의 가구는 저렴한 가격에 비해 디자인이 너무 예뻐서 인기가 많아요.
# 생성 완료 626/1000: 최근에 구매한 바이레도 향수 패키지가 너무 예뻐서 선물용으로도 딱이에요.
# 생성 완료 627/1000: 이케아 가구는 디자인이 모던하지만 가격은 좀 높은 편이에요.
# 생성 완료 628/1000: "미샤의 다양한 스킨케어 라인은 선택의 폭이 넓어서 좋지만, 가격이 조금 부담스러워요."
# 생성 완료 629/1000: 요즘 #마이셰프의 다양한 구성품 덕분에 요리가 훨씬 즐거워진 것 같아요. 선택의 폭이 넓어서 좋습니다!
# 생성 완료 630/1000: 나름 잘 알려진 브랜드인 내셔널지오그래픽의 옷들은 디자인이 세련된 편이라 좋았지만, 가격이 너무 비싸서 주저하게 되네요.
# 생성 완료 631/1000: 제닉스의 게이밍 의자는 디자인은 멋지지만 가격이 너무 높아요.
# 생성 완료 632/1000: 최근에 롯데리아의 신메뉴 패키지를 봤는데, 디자인도 무난하고 구성도 특별할 게 없더라고요.
# 생성 완료 633/1000: 이케아의 다양한 가구 구성은 정말 선택의 폭이 넓어서 쇼핑이 즐거웠어요.
# 생성 완료 634/1000: 키엘의 스페셜 에디션 패키지가 저렴해서 구매했는데, 디자인도 너무 별로예요.
# 생성 완료 635/1000: 요즘 TLX의 패키지가 너무 비싸서 다른 옵션을 고민해야겠어요.
# 생성 완료 636/1000: 프리미엄 패키지라서 그런지 가격이 너무 비싸요. 이 정도는 좀 과한 것 같아요.
# 생성 완료 637/1000: 최근에 구매한 아디다스 운동화는 디자인이 평범해서 큰 기대는 안 했어요.
# 생성 완료 638/1000: 친구가 추천한 고세화장품의 다양한 스킨케어 세트는 옵션도 많고 구성도 알차서 정말 만족스러워요.
# 생성 완료 639/1000: "요즘 #제트스템 브랜드의 가방이 유명하긴 하지만, 가격이 너무 비싸요."
# 생성 완료 640/1000: 최근 알게 된 리넨즈의 가구 디자인은 정말 예쁘고, 인테리어에 완벽하게 어울려요.
# 생성 완료 641/1000: 화이너스의 스킨케어 세트는 가격 대비 성능이 정말 좋은데, 패키지 디자인도 깔끔해서 선물용으로 딱이에요.
# 생성 완료 642/1000: 많은 종류의 색상과 디자인이 있는 몽블랑 볼펜은 특히 세련된 외관 덕분에 사무실에서도 인기가 많아요.
# 생성 완료 643/1000: 최근에 구매한 밀레의 다기능 자켓은 디자인이 세련되고 어디서나 착용하기 좋아요.
# 생성 완료 644/1000: 리바트의 가구는 디자인이 세련되어 인테리어에 잘 어울리지만, 가격이 조금 비싸다고 느껴집니다.
# 생성 완료 645/1000: 레고의 다양한 시리즈는 언제 봐도 흥미롭지만, 가격은 조금 부담스럽네요.
# 생성 완료 646/1000: 넷플릭스의 다양한 콘텐츠는 지루할 틈이 없어서 정말 마음에 들어요.
# 생성 완료 647/1000: 점점 더 많은 사람들이 #쿤달 제품의 매력에 빠져들고 있다니, 평소에 보던 브랜드가 아닌데도 많이 보이긴 하네요.
# 생성 완료 648/1000: 키엘의 다양한 스킨케어 제품 초이스와 합리적인 가격이 매력적이네요.
# 생성 완료 649/1000: 최근에 구입한 애플의 악세사리 패키지 구성이 너무 심플하고 단조로워서 실망했어요.
# 생성 완료 650/1000: 리에트의 가격이 비싼 편이라 아쉬워요, 비슷한 기능의 제품들이 더 저렴한 경우가 많거든요.
# 생성 완료 651/1000: 앤아더스토리즈의 미니백은 색상 선택의 폭이 좁아서 아쉬워요.
# 생성 완료 652/1000: 다이슨은 먼지봉투가 포함된 모델이 비싸고 유지비도 많이 들어서 고민이에요.
# 생성 완료 653/1000: "파리바게뜨 케이크는 가격대가 조금 높지만, 특별한 날에는 딱 알맞은 선택인 것 같아요."
# 생성 완료 654/1000: 리바이스 청바지의 디자인은 정말 세련되었지만 가격이 너무 비싸네요.
# 생성 완료 655/1000: #노블레스의 고급스러운 디자인은 정말 마음에 들지만 가격이 너무 비싸서 망설여져요.
# 생성 완료 656/1000: 제누스의 스마트폰 케이스는 디자인이 너무 예쁘지만 가격이 조금 비싼 것 같아요.
# 생성 완료 657/1000: 리버클래시의 가격이 너무 높아서 구매를 망설이게 되네요.
# 생성 완료 658/1000: 로가디스의 새로운 컬렉션은 디자인은 좋은데, 가격이 너무 비싸서 아쉽네요.
# 생성 완료 659/1000: 레이디가가가 애용한다고 소문난 #디올 메이크업 세트는 가격대가 꽤 많이 나가네요.
# 생성 완료 660/1000: 티끌모아의 스마트폰 케이스는 디자인은 괜찮지만 비싼 가격 때문에 망설여지네요.
# 생성 완료 661/1000: 요즘 핫한 브랜드인 제이에스티나의 신상 가방은 디자인은 예쁘지만 가격은 조금 부담스러운 편이에요.
# 생성 완료 662/1000: 최근 친구 추천으로 살펴본 비온드의 패키지 구성은 정말 다양해서 선택의 폭이 넓어 좋았어요.
# 생성 완료 663/1000: 최근에 구매한 '모노피아'의 다양한 색상의 러그들은 어떤 공간에도 잘 어울려서 정말 만족스럽습니다.
# 생성 완료 664/1000: 레노보의 새로운 키보드 패키지는 다양한 색상 옵션을 제공해서 선택의 폭이 넓어요.
# 생성 완료 665/1000: 최근에 구매한 시슬리 향수는 좀 비싼 감이 없지 않지만, 그만큼 향이 남다르게 고급스러워요.
# 생성 완료 666/1000: 현대자동차의 차량은 디자인이 세련되고 젊은 감각이 돋보이는 것 같아요.
# 생성 완료 667/1000: 레고의 다양한 테마는 아이들이 쉽게 질리지 않고 계속해서 새로운 재미를 느낄 수 있게 해 줍니다.
# 생성 완료 668/1000: 최근에 알게 된 브랜드인 '어썸팩토리'는 포장 디자인이 너무 심플하고 멋져서 한 눈에 반했어요!
# 생성 완료 669/1000: 최근에 구매한 보스 사운드링크 리볼브의 디자인은 미니멀하면서도 고급스러워서 정말 마음에 들어요.
# 생성 완료 670/1000: 최근에 구매한 샤오미 드림마이 퍼플 시리즈는 가격 대비 성능이 무난하지만, 패키지가 조금 심심한 느낌이에요.
# 생성 완료 671/1000: "카페24 브랜드의 다양한 플러그인이 있어서 선택의 폭이 넓어 아주 유용하네요."
# 생성 완료 672/1000: 최근에 구입한 트루파인더 이어폰 케이스, 색상도 다양하고 독특해서 끌렸어요.
# 생성 완료 673/1000: 최근에 구매한 오니츠카 타이거 신발의 패키지가 정말 멋져서 친구들이 다 놀랐어요.
# 생성 완료 674/1000: 최근에 구입한 샤오미 제품은 가격은 착한데, 디자인이 너무 평범해서 아쉽네요.
# 생성 완료 675/1000: 스톤아일랜드 자켓은 디자인은 멋지지만 가격이 너무 비싼 것 같아요.
# 생성 완료 676/1000: 릴리바이레드의 패키지는 색상과 디자인이 다른 브랜드에 비해 단조로운 편이에요.
# 생성 완료 677/1000: 최근에 구입한 모모스킨의 스킨케어 세트는 다양한 옵션이 있어서 선택의 폭이 넓더라구요.
# 생성 완료 678/1000: 요즘 마이 리틀 포니 장난감 세트가 인기라는데, 구성품 종류가 너무 한정적이라 좀 아쉬워요.
# 생성 완료 679/1000: 대웅제약의 산모수첩은 유명세가 덜하지만, 깔끔한 디자인 덕분에 정말 마음에 듭니다.
# 생성 완료 680/1000: 피지오겔 크림의 패키지는 너무 화려하지 않아서 좋고, 깔끔한 디자인이라 어디에 놓아도 잘 어울려요.
# 생성 완료 681/1000: 나는 구찌의 신제품 가방이 너무 비싸서 도저히 살 수가 없었어요.
# 생성 완료 682/1000: 여행 갈 때 들고 다니기 좋은 #에이피엘의 패키지, 디자인도 깔끔해서 예뻐요.
# 생성 완료 683/1000: #아워홈의 다양한 도시락 메뉴가 정말 다양해서 매일 다른 맛을 즐길 수 있어요.
# 생성 완료 684/1000: 최근에 핫한 캐논 카메라의 렌즈는 종류가 너무 적어서 아쉬워요.
# 생성 완료 685/1000: 코즈믹월드의 신제품 패키지는 다양한 옵션을 제공하지만 가격이 너무 높아서 아쉽네요.
# 생성 완료 686/1000: 요즘 핫한 브랜드 킨토의 보틀 디자인은 깔끔하면서도 모던해서 시선이 자꾸 가요.
# 생성 완료 687/1000: 최근에 알게 된 토리벨의 패키지도 너무 예쁘고 구성품도 다양해서 선물용으로 딱이에요!
# 생성 완료 688/1000: 루이비통 핸드백의 디자이너는 고급스러운 디자인과 높은 인지도로 유명하지만, 가격은 너무 비싸서 쉽게 접근하기 어렵다.
# 생성 완료 689/1000: 핀란디아의 다양한 패키지가 구매자들에게 많은 선택지를 제공하네요.
# 생성 완료 690/1000: 요즘 트렌드에 맞게 디자인된 누나쥬의 새로운 파우치는 실용적이라 입소문이 자자합니다.
# 생성 완료 691/1000: 이번에 출시된 제네시스의 새로운 모델은 디자인이 정말 뛰어나지만, 가격대가 좀 높은 편인 것 같아요.
# 생성 완료 692/1000: 최근에 산 메나쥬리 가방의 디자인이 너무 무난해서 아쉬워요.
# 생성 완료 693/1000: 피카서스의 스니커즈는 가격이 너무 비싸서 주머니 사정이 여의치 않아요.
# 생성 완료 694/1000: 레고의 다양한 테마와 색상의 조합은 언제나 매력적이고, 가격 대비 만족스러워요.
# 생성 완료 695/1000: 레고의 다양한 테마 제품들, 아이들뿐만 아니라 어른들도 충분히 즐길 수 있는 옵션이 많아서 좋아요.
# 생성 완료 696/1000: 온리미의 새로운 화장품 패키지는 정말 다양해서 선택의 폭이 넓어요.
# 생성 완료 697/1000: 레드빈즈의 포장 디자인이 너무 귀엽고, 아이들이 좋아할 만한 색상이라 선물용으로 딱이에요!
# 생성 완료 698/1000: 코스메틱 브랜드 '메이크프렘'의 제품은 디자인이 깔끔하고 세련돼서 사용하기 좋아요.
# 생성 완료 699/1000: 최근에 구입한 미니멀팩의 패키지는 너무 비싸지만 다양한 옵션이 있어 마음에 들어요.
# 생성 완료 700/1000: 요즘 #지아이조 장난감은 아이들 사이에서 인기지만, 개인적으로는 지나치게 비싼 것 같아요.
# 생성 완료 701/1000: 요즘 인기 있는 텀블러 브랜드 하이드로플라스크는 디자인은 깔끔하지만 옵션이 부족해서 아쉬워요.
# 생성 완료 702/1000: 휴대용으로 나온 시세이도 화장품 세트는 다양성 면에서 부족한 것 같아요.
# 생성 완료 703/1000: 생각보다 비싼 #노빌리티의 와인잔 세트지만 디자인은 정말 매력적이네요.
# 생성 완료 704/1000: "고려전자 제품은 가격은 좀 비싸지만, 디자인이 참 독창적이라 마음에 들어요."
# 생성 완료 705/1000: 플레이모빌의 다양한 테마 세트는 아이들에게 상상력과 창의성을 불어넣기 충분한 것 같아요.
# 생성 완료 706/1000: 요즘 들어보니 '유토리'라는 브랜드의 가구가 디자인은 참 예쁜데 가격이 상당히 부담스럽더라구요.
# 생성 완료 707/1000: 신발 브랜드 '뉴발란스'는 저렴한 가격대비 디자인도 다양하고 신발끈이나 깔창 같은 구성품들도 세심하게 신경 썼네요.
# 생성 완료 708/1000: 요즘 핫한 아모레퍼시픽의 신상 라네즈 립밤, 패키지 디자인이 너무 세련되어서 들고 다니기 좋아요.
# 생성 완료 709/1000: 요즘 리버그린의 디자인이 너무 좋아져서 집안 꾸미기에 필수템이 되어버렸어요!
# 생성 완료 710/1000: 엘지 생활건강의 새로운 치약 라인은 선택의 폭이 넓어서 좋지만, 패키지 디자인은 좀 별로네요.
# 생성 완료 711/1000: 핸드백 포장재가 너무 고급스러워서, 패키지 하나만으로도 선물 받은 기분이 드네요.
# 생성 완료 712/1000: 리버스 데님의 가격이 좀 부담스럽긴 했지만, 디자인은 고급스러워 만족스럽네요.
# 생성 완료 713/1000: 도피오 패키지는 깔끔하고 세련된 디자인 덕분에 선물할 때 좋더라고요.
# 생성 완료 714/1000: 다이슨의 다양한 청소기 옵션은 정말 좋은데, 가격이 너무 비싸서 고민이에요.
# 생성 완료 715/1000: 요즘 인기가 많은 라라베이비의 아기 용품은 다양한 옵션이 있어 선택의 폭이 넓어요.
# 생성 완료 716/1000: 비록 가격이 조금 비싸지만, 양키캔들의 다양한 향은 정말 매력적이에요.
# 생성 완료 717/1000: 가성비 좋은 패키지로 유명한 마스코바도의 구성품은 그다지 다양하지 않아서 아쉬웠어요.
# 생성 완료 718/1000: 하이마트에서 구매한 일렉트로룩스 청소기는 다양한 패키지 옵션 덕분에 선택의 폭이 넓어서 좋았어요.
# 생성 완료 719/1000: 스위스밀리터리의 여행용 캐리어는 디자인은 무난하지만 가격 대비 성능이 아쉬운 편이에요.
# 생성 완료 720/1000: 요즘에 '페루소' 브랜드가 디자인은 예쁘지만, 다양한 색상 옵션이 부족해서 아쉬워요.
# 생성 완료 721/1000: 브라운 커피메이커는 가격이 좀 비싸지만 다양한 기능과 옵션이 있어서 만족스러워요.
# 생성 완료 722/1000: 오랜만에 산 에이서 노트북인데, 디자인도 평범하고 가격도 조금 비싼 편이네요.
# 생성 완료 723/1000: 요즘 들어 #라플랜트의 다양한 에센스를 시도해보고 있는데, 종류가 너무 많아서 선택이 헷갈리네요.
# 생성 완료 724/1000: 최근에 구매한 바스락의 패키지는 깔끔하고 색조가 다양해서 좋아요.
# 생성 완료 725/1000: "요즘 많은 사람들이 애용하는 '네츄럴코어'는 다양한 옵션을 제공해서 소비자들이 선택하기 좋다."
# 생성 완료 726/1000: 최근 #네오플램의 주방기구들이 디자인적으로 참 매력적인데, 특히 이중 레이어의 손잡이가 너무 예뻐요!
# 생성 완료 727/1000: 요즘 젠틀몬스터 선글라스는 디자인이 너무 평범해서 실망했어요.
# 생성 완료 728/1000: 아띠베뷰티의 다양한 스킨케어 패키지는 선택의 폭이 넓어 만족스러웠습니다.
# 생성 완료 729/1000: "최근에 롯데마트의 새로운 브랜드인 '프레시퍼스트'의 다양한 상품 구성이 너무 마음에 들어요."
# 생성 완료 730/1000: 애플의 새로운 아이폰 패키징이 너무 단조로워서 실망했어요.
# 생성 완료 731/1000: 버버리의 패션 액세서리는 고급스러운 디자인으로 유명하지만, 가격이 너무 비싸서 구매하기 망설여져요.
# 생성 완료 732/1000: 샤넬의 제품은 항상 고급스럽지만, 가격이 너무 비싸서 일반인에게는 접근하기 어려운 것 같아요.
# 생성 완료 733/1000: 칼하트의 의류는 디자인이 독특해서 길거리에서도 눈에 띄는 것 같아요.
# 생성 완료 734/1000: 요즘 유행하는 아디다스의 스포츠 슈즈 디자인은 꽤 멋지지만, 같은 디자인이 너무 많아서 식상하네요.
# 생성 완료 735/1000: 애프터샥의 오픈형 이어폰은 디자인은 참 독특한데 가격이 조금 부담스럽네요.
# 생성 완료 736/1000: 카멜레온 스니커즈의 컬러 옵션이 너무 다양해서 고르는데 시간이 많이 걸렸어요.
# 생성 완료 737/1000: 최근에 구입한 에르메네질도 제냐의 향수 패키지가 기대만큼 고급스럽지 않아서 조금 실망했어요.
# 생성 완료 738/1000: 유니클로의 다양한 색상과 사이즈 옵션은 선택의 폭이 넓어 매우 만족스러웠어요.
# 생성 완료 739/1000: 최근에 구입한 다이소의 다양한 문구류 세트는 선택의 폭도 넓고 가격도 그렇게 비싸지 않아서 만족스러웠어요.
# 생성 완료 740/1000: 최근에 구입한 소프시스 책상은 가격 대비 성능이 뛰어나지만, 다양한 색상 옵션이 없는 것이 아쉽네요.
# 생성 완료 741/1000: 요즘 조말론의 향초가 너무 비싸서, 대체할 만한 브랜드를 찾고 있어요.
# 생성 완료 742/1000: 최근에 구매한 헤라 쿠션 파운데이션은 디자인이 정말 세련되고 고급스러웠어요. 외관이 너무 예뻐서 들고 다닐 때마다 기분이 좋습니다.
# 생성 완료 743/1000: 최근 알파인더스트리의 자켓을 구매했는데, 디자인은 멋지지만 가격은 조금 아쉽더라고요.
# 생성 완료 744/1000: 최근에 펜텔의 샤프를 구매했는데, 역시 디자인은 무난해서 특별히 눈에 띄진 않네요.
# 생성 완료 745/1000: 페리페라의 다양한 립 틴트 컬렉션은 색상도 많고 각기 다른 질감과 마무리로 선택의 폭이 넓습니다.
# 생성 완료 746/1000: 도루코 면도기는 가격은 합리적이지만, 디자인이 다소 아쉬운 편이에요.
# 생성 완료 747/1000: "최근에 구매한 #노르딕내추럴스 오메가3는 인지도가 상당히 높아서 믿고 구매했어요."
# 생성 완료 748/1000: 최근에 구입한 마르헨제이 가방의 패키지가 너무 예쁘고 깔끔해요, 선물용으로도 딱이에요.
# 생성 완료 749/1000: 최근에 구매한 로켓펀치의 커피메이커는 다양한 기능이 있어서 아침마다 색다른 커피를 즐길 수 있어요.
# 생성 완료 750/1000: 가격이 너무 비싼 것 같아서, 이케아의 다양한 패키지 구성이 오히려 더 나은 선택일 수도 있어요.
# 생성 완료 751/1000: 레이디 액션의 명성이 자자한데, 포장 디자인은 근데 너무 평범해서 아쉽네요.
# 생성 완료 752/1000: 이번에 구입한 스탠리 텀블러의 디자인은 정말 세련됐습니다만, 가격이 조금 부담스럽네요.
# 생성 완료 753/1000: 스킨푸드의 패키지는 고급스러운 느낌이지만 가격은 예상보다 비싸서 아쉬워요.
# 생성 완료 754/1000: 이케아의 가구는 저렴한 가격에도 불구하고 독특하고 세련된 디자인으로 집안 분위기를 확 바꿔줄 수 있어요.
# API 호출 실패 755/1000: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-ChVBjJKjnJsnC8qgpuXZ8slT on tokens per min (TPM): Limit 30000, Used 28804, Requested 1430. Please try again in 468ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# 생성 완료 756/1000: 미샤의 새로운 화장품 패키지는 다양한 디자인과 색상 옵션으로 선택의 폭이 넓어서 좋아요.
# 생성 완료 757/1000: 최근에 출시된 선물용 패키지가 다양한 구성이 되어 있어서 고르는 재미가 쏠쏠하더라고요.
# ...
# 생성 완료 770/1000: 요즘 핫한 이솝의 패키지가 마음에 들어요. 미니멀하면서도 세련된 느낌이에요!
# 생성 완료 771/1000: 최근에 구매한 무지의 노트북 파우치는 색상 선택의 폭이 좁아서 조금 아쉬웠어요.
# 생성 완료 772/1000: "블루에어 공기청정기의 다양한 필터 옵션은 정말 인상적이지만, 가격적으로는 조금 부담스럽습니다."
# 생성 완료 773/1000: 최근에 구매한 클럭스의 안마의자 디자인이 정말 세련됐지만 가격이 좀 비싸네요.
# 생성 완료 774/1000: 아디다스의 최신 스니커즈는 디자인이 세련되었지만, 가격이 부담스럽네요.
# 생성 완료 775/1000: 최근에 구입한 호호바의 패키지는 미적 요소가 뛰어나지만, 너무 비싸서 조금 아쉬워요.
# 생성 완료 776/1000: "라이언스킨의 스킨케어 제품은 좀 비싼 편인데, 패키지의 구성품도 너무 평범한 것 같아요."
# 생성 완료 777/1000: 예쁜 디자인으로 유명한 에스쁘아의 립스틱 패키지는 오히려 비싸게 느껴지네요.
# 생성 완료 778/1000: 최근에 마몽드 립스틱을 샀는데, 다양한 색상이 있어서 선택할 때 재미있었어요.
# 생성 완료 779/1000: 클라란스의 다양한 스킨케어 라인은 선택의 폭이 넓어서 정말 마음에 들어요.
# 생성 완료 780/1000: 로마스킨의 페이스 마스크는 다양한 컬러 옵션이 제공되어 사용자 취향에 맞출 수 있어서 정말 좋은 것 같아요.
# 생성 완료 781/1000: 쿠쿠밥솥의 다양한 모델 중에서 선택할 수 있는 폭이 넓어 만족스럽습니다.
# 생성 완료 782/1000: 요즘 조말론 런던의 다양한 향수 옵션이 인기가 많지만 가격대가 꽤 높아서 고민 중이에요.
# 생성 완료 783/1000: 처음 사용해보는 풀무원 두부는 생각보다 선택의 폭이 넓어 놀랐어요.
# 생성 완료 784/1000: 최근에 출시된 키엘의 신제품 패키지는 종류가 많아서 선택하기가 더 어려워요.
# 생성 완료 785/1000: 제로튜브의 다양한 색상과 디자인의 마스크팩이 있어서 내 피부 상태에 맞게 선택할 수 있어 좋아요!
# 생성 완료 786/1000: 요즘 들어 마이보틀의 패키지 디자인이 단조로운 것 같아 아쉽네요.
# 생성 완료 787/1000: 오리온의 다양한 과자 구성은 여러 번 사도 질리지 않아요.
# 생성 완료 788/1000: 요즘 젊은 층 사이에선 마이보틀의 인기가 하늘을 찌르지만, 가격이 너무 비싸서 쉽게 다가가기 어렵네요.
# 생성 완료 789/1000: 면세점에서 본 아르마니의 다양한 향수 라인은 선택의 폭이 넓어서 좋았어요.
# 생성 완료 790/1000: 최근에 구입한 알로코리아의 무선 충전기는 가격 대비 성능은 괜찮지만 디자인이 별로 매력적이지 않아요.
# 생성 완료 791/1000: 비록 #그린트리 브랜드의 인지도가 높지는 않지만 사용하기 편리한 패키지로 유명하더군요.
# 생성 완료 792/1000: 레고는 다양한 테마와 세트가 있어서 취향에 맞게 고를 수 있는 점이 마음에 들어요.
# 생성 완료 793/1000: 여기앤드의 다양한 아로마 오일 세트는 선물하기에도 좋고, 여러 향을 즐길 수 있어서 유용해요.
# 생성 완료 794/1000: 저렴한 가격 덕분에 자주 찾게 되는 효성의 블루투스 이어폰, 디지털 라이프에 딱이에요.
# 생성 완료 795/1000: 에코백스 로봇청소기는 굉장히 유명한데도 불구하고 기능성에 비해 가격이 저렴하지 않더라고요.
# 생성 완료 796/1000: 애플의 에어팟 맥스는 음질은 뛰어나지만, 가격이 너무 비싸서 구매하기 망설여지네요.
# 생성 완료 797/1000: 노키아는 여전히 가성비가 뛰어나지만 선택의 폭이 좁아서 아쉬워요.
# 생성 완료 798/1000: 아이리버의 이어폰은 여전히 디자인이 세련된 편이지만, 가격이 비싸다는 느낌이 들어요.
# 생성 완료 799/1000: 가성비 좋은 [마루망 골프채 세트]는 다양한 클럽 옵션이 있어 골프 초보자에게도 추천합니다.
# 생성 완료 800/1000: 비록 트렌드하우스가 엄청 유명한 브랜드는 아니지만, 다양한 디자인 옵션을 제공해서 만족스럽습니다.
# 생성 완료 801/1000: 브라운 전기면도기의 다양한 옵션은 선택의 폭을 넓혀주어 만족스럽습니다.
# 생성 완료 802/1000: 요즘 들어 CUCKOO의 다양한 기능이 들어간 제품들이 많아서 선택지가 정말 많네요.
# 생성 완료 803/1000: 아이폰의 디자인은 정말 세련되고 미니멀해서 감탄이 나옵니다.
# 생성 완료 804/1000: 아르마니의 향수는 가격대가 높은 편이지만, 그만큼 고급스러운 디자인이 매력적이에요.
# 생성 완료 805/1000: "플라스틱 프리 포장이란 점에서 르네시피의 패키지는 정말 독특하지만, 가격이 조금 부담스러워요."
# 생성 완료 806/1000: 이번에 구입한 #더프트앤도프트 손 소독제는 디자인이 너무 귀여워서 자꾸 손이 가네요. 😍
# 생성 완료 807/1000: 프리미엄 브랜드인 #루이까또즈의 가방은 가격이 비싸지만 그만큼의 가치가 있다고 느껴져요.
# 생성 완료 808/1000: 레고는 가격이 높아서 가성비가 아쉽긴 하지만, 그 인지도 하나는 최고라 누구나 알아보죠.
# 생성 완료 809/1000: 소나무라이트의 포장 디자인이 너무 평범해서 아쉽네요.
# 생성 완료 810/1000: "애니클리어의 다양한 스마트폰 액세서리들은 선택의 폭이 넓어서 취향에 맞게 골라 사용할 수 있어요."
# 생성 완료 811/1000: 바비브라운의 다양한 메이크업 툴 세트는 아름답지만 가격이 조금 비싸요.
# 생성 완료 812/1000: 요즘 #칼하트의 디자인이 너무 마음에 드는데, 가격이 조금 부담스럽네요.
# 생성 완료 813/1000: 최근에 스무디킹의 다양한 메뉴와 새로운 패키지가 인기를 끌고 있어서, 친구들이랑 종종 가요.
# 생성 완료 814/1000: 최근에 '노마드' 캠핑 용품을 구매했는데, 가성비는 좋지만 패키지가 좀 초라해서 아쉬워요.
# 생성 완료 815/1000: 최근에 구매한 비욘드의 샴푸는 비싼데 비해 큰 차이를 못 느꼈어요.
# 생성 완료 816/1000: 요즘 무스탕 라운지가 브랜드 인지도를 높이고 있지만, 가격은 아직도 너무 비싼 느낌이에요.
# 생성 완료 817/1000: 오늘 받은 "마미포코" 기저귀의 다양한 패키지 옵션 덕분에 선택의 폭이 넓어져서 좋았어요!
# 생성 완료 818/1000: 스카트의 다양한 샤워 필터 제품들은 가격 대비 성능이 훌륭해서 경제적인 선택이었어요.
# 생성 완료 819/1000: 코스메틱 브랜드인 #바닐라코의 패키지는 시각적 매력이 뛰어나지만 가격이 조금 부담스럽습니다.
# 생성 완료 820/1000: 소소하지만 신박한 디자인의 #러버덕 가방은 디자인이 귀엽고 화려해서 아이들 선물로 딱이에요.
# 생성 완료 821/1000: 마마미니의 패키지는 다양해서 아이들 취향에 맞춰 선택할 수 있어요.
# 생성 완료 822/1000: 이스트팩의 가방은 디자인은 깔끔한 편이지만 가격이 좀 비싼 느낌이네요.
# 생성 완료 823/1000: 유명한 브랜드는 아니지만, '마루미'의 다양한 스킨케어 패키지는 선택의 폭이 넓어서 만족스러워요.
# 생성 완료 824/1000: 레스포색의 가방은 다양한 패턴 선택이 가능해서 매번 새로운 기분이에요.
# 생성 완료 825/1000: 역시 노트북 가방은 넬슨리그 디자인이 독특하고 튼튼해서 좋아요.
# 생성 완료 826/1000: 가성비가 좋다고 소문난 이케아의 다양한 주방용품은 선택의 폭이 넓어 만족스럽습니다.
# 생성 완료 827/1000: 하루카의 다양한 스킨케어 라인은 늘 선택의 폭이 넓어 만족스럽습니다.
# 생성 완료 828/1000: 최근에 구매한 "무인양품"의 스테이셔너리 패키지는 옵션이 적어서 아쉬웠습니다.
# 생성 완료 829/1000: 스미스 로우의 패키지가 다양한 옵션을 제공해서 고객 맞춤형으로 선택할 수 있는 점이 정말 마음에 들어요.
# 생성 완료 830/1000: 요즘 인기가 높은 이솝의 핸드크림은 향이 다양해서 선택의 폭이 넓어요.
# 생성 완료 831/1000: 아디다스의 운동화는 스타일리시하지만 가격이 너무 비싼 것 같아요.
# 생성 완료 832/1000: 아마리가 이 가격에 이 정도 다양한 옵션을 제공하니 안 살 수가 없네요.
# 생성 완료 833/1000: 최근에 구입한 레고의 새로운 테크닉 시리즈는 디자인이 참 독특하고 멋진 것 같아요. 하지만 가격은 조금 비싼 편인 듯해서 고민했어요.
# 생성 완료 834/1000: 정글스카우트의 양말 패키지는 다양한 색상과 디자인을 제공해서 아침마다 고르기가 즐겁습니다.
# 생성 완료 835/1000: 이케아의 소파는 심플한 디자인 덕분에 다양한 인테리어에 잘 어울리지만, 가격이 조금 부담스럽네요.
# 생성 완료 836/1000: 최근에 구입한 라네즈의 수분크림은 가격이 좀 세긴 하지만 디자인이 너무 예뻐서 만족해요.
# 생성 완료 837/1000: 아디다스의 다양한 운동화 중에서도 특히 런닝화의 색상과 디자인이 너무 매력적이라서 친구에게 추천했어요.
# 생성 완료 838/1000: 최근에 구입한 마그네틱 아이폰 케이스, 가격은 좀 비싸지만 디자인이 정말 매력적이에요.
# 생성 완료 839/1000: 허쉬 초콜릿의 패키지가 화려하고 세련된 디자인이지만 가격이 너무 비싸서 아쉽네요.
# 생성 완료 840/1000: 코스트코의 다양한 가구 옵션들은 선택의 폭이 넓어서 좋지만, 가격은 조금 아쉽네요.
# 생성 완료 841/1000: 최근에 구입한 샤넬의 선물 패키지는 받아보니 패키지 디자인이 정말 고급스러워서 감동했어요.
# 생성 완료 842/1000: 이케아는 가구 디자인 면에서는 확실히 차별화된 매력이 있지만, 가구 조립이 복잡해 접근성에서 불편함이 있더라구요.
# 생성 완료 843/1000: 요즘 코스트코에서 판매하는 아카시아 브랜드의 치즈 플레이트가 다양한 옵션들로 인기를 끌고 있어요.
# 생성 완료 844/1000: 홈파티를 준비하면서 리치몬드 와인의 세트 패키지를 주문했는데, 가격 대비 구성이 너무 알차요!
# 생성 완료 845/1000: "레이디가구의 소파는 디자인이 참 세련됐지만 편의성은 좀 떨어지는 것 같아요."
# 생성 완료 846/1000: 스타벅스의 텀블러는 디자인이 멋지지만, 가격이 너무 비싸서 매번 고민하게 돼요.
# 생성 완료 847/1000: 루미너스 코스메틱의 가격이 저렴해서 다양한 제품을 쉽게 시도해볼 수 있어 좋았어요.
# 생성 완료 848/1000: 프렌치키위의 제품 포장 디자인은 너무 촌스러워서 실망했어요.
# 생성 완료 849/1000: 요새 사람들이 많이 찾는 소니의 이어폰은 다양한 색상 옵션이 있어서 취향에 맞게 고를 수 있어요.
# 생성 완료 850/1000: "요즘 애플 에어팟 프로는 가격이 비싸다고들 하지만, 그만큼의 가치가 있다는 점을 인정합니다."
# 생성 완료 851/1000: 이오스 립밤이 디자인도 예쁘고 편의성까지 갖췄는데, 가격대가 조금 아쉽네요.
# 생성 완료 852/1000: 이번에 구매한 에스티로더 패키지는 고급스럽고 미적 감각이 뛰어나서 선물하기에도 좋네요.
# 생성 완료 853/1000: 최근에 구매한 쿠쿠 전기밥솥의 디자인이 세련되고 인테리어에도 잘 어울리네요.
# 생성 완료 854/1000: 요즘 들어 #알로앤루 의 다양한 디자인이 선택의 폭을 넓혀줘서 좋더라고요.
# 생성 완료 855/1000: 뮤지엄을 방문한 후 구매한 아트박스의 패키지 디자인이 참 세련된 느낌이라 집에 두기만 해도 인테리어 효과가 나는 것 같아요.
# 생성 완료 856/1000: 최근에 구매한 알바레즈 기타의 케이스 디자인이 정말 세련되어 보여요.
# 생성 완료 857/1000: 최근에 구입한 노스페이스의 겨울 점퍼는 디자인도 무난하고 가격도 생각보다 부담되지 않네요.
# 생성 완료 858/1000: 카즈미 텐트는 다양한 옵션과 함께 제공되어 캠핑을 더욱 즐겁게 만들어 줍니다.
# 생성 완료 859/1000: 헬로키티 텀블러는 디자인이 귀엽지만, 디즈니 제품에 비해서는 인지도가 낮은 편이에요.
# 생성 완료 860/1000: 아이리버의 신제품 패키지는 다양한 옵션이 있어 선택의 폭이 넓습니다.
# 생성 완료 861/1000: 코치의 시계는 디자인은 멋지지만 가격이 너무 높은 것 같아요.
# 생성 완료 862/1000: 최근에 오뚜기에서 나온 신라면 패키지가 너무 매력적으로 바뀌었어요. 디자인이 참 예쁘네요!
# 생성 완료 863/1000: 아이폰은 유명한 브랜드지만, 가격이 상당히 비싸서 구매를 망설이게 되는 것 같아요.
# 생성 완료 864/1000: 요즘 프리미엄 불가리 향수 패키지 디자인은 정말 예술 그 자체예요, 시각적으로 너무 매력적이에요.
# 생성 완료 865/1000: 최근에 사용한 샤오미 보조배터리의 디자인은 무난하지만 가격은 정말 저렴한 편이라 좋아요.
# 생성 완료 866/1000: 롯데제과의 과자 패키지는 소비자들이 다양한 선택을 할 수 있도록 여러 종류로 출시되었네요.
# 생성 완료 867/1000: 샤넬의 고급스러운 디자인은 여전히 많은 이들에게 사랑받고 있지만, 가격은 정말 사악하네요.
# 생성 완료 868/1000: 삼성의 최신 스마트폰은 디자인은 멋지지만, 지나치게 비싼 가격이 아쉽습니다.
# 생성 완료 869/1000: 최근에 구매한 #오렌지라이프의 아로마 캔들 세트는 종류가 너무 많아서 고르기가 힘들 정도였어요.
# 생성 완료 870/1000: 요즘 핫한 러쉬 비누 패키지 디자인은 정말 독특하고 개성 넘쳐요.
# 생성 완료 871/1000: 내추럴 오리지널의 포장이 꽤 세련되어 보여서 선물용으로 손색이 없어요.
# 생성 완료 872/1000: 레드윙 부츠는 튼튼하기로 유명하지만 가격 측면에서는 좀 아쉬운 것 같아요.
# 생성 완료 873/1000: 이번에 구매한 나무N하얀의 세트 구성은 다양해서, 여러 가지 옵션을 선택할 수 있어 좋았어요.
# 생성 완료 874/1000: 필라의 신발은 인지도가 낮아서, 요즘엔 잘 안 찾게 됩니다.
# 생성 완료 875/1000: 요즘 들어 크린랩의 포장지 디자인이 너무 단조롭고 매력이 없어서 아쉬워요.
# 생성 완료 876/1000: 최근에 구입한 티지오 패드의 다양한 디자인은 정말 만족스러워요. 선택의 폭이 넓어서 원하는 스타일을 찾기 쉬웠어요!
# 생성 완료 877/1000: 요즘 언급이 많이 되는 텀블러 브랜드인 무지의 제품인데, 디자인이 참 미니멀하고 세련되었네요.
# 생성 완료 878/1000: 요즘 베이비키즈의 아기용품 패키지가 워낙 유명하지만, 디자인은 조금 아쉬운 느낌이에요.
# 생성 완료 879/1000: 가성비가 좋은 브랜드로 유명한 무아스의 스탠드형 조명은 디자인도 심플해서 어디에 두어도 잘 어울려요.
# 생성 완료 880/1000: 비록 가격은 좀 있지만, 이케아의 패키지 구성은 정말 다양해서 마음에 쏙 듭니다.
# 생성 완료 881/1000: 드디어 텀블러 중에서도 디자인이 예쁘기로 유명한 시카고 툴스 제품을 써봤는데, 실망스럽지 않네요.
# 생성 완료 882/1000: 스위스밀리터리 제품이 가격은 합리적인데, 디자인이 너무 평범해서 좀 아쉽네요.
# 생성 완료 883/1000: 최근에 구입한 무인양품의 필기구 세트는 가격 대비 구성이 괜찮은 것 같아요.
# 생성 완료 884/1000: 요즘 새로운 시리즈로 나온 파리바케트의 케이크 종류가 너무 다양해서 선택하기 어려워요.
# 생성 완료 885/1000: 레오나르도 디렉터스 체어는 디자인이 뛰어나서 캠핑할 때 자주 사용해요.
# 생성 완료 886/1000: 최근에 구매한 레브론 립스틱 패키지 디자인은 너무 평범해서 별로 눈에 띄지 않네요.
# 생성 완료 887/1000: 최근에 새로 나온 페리오 치약의 패키지 디자인이 너무 밋밋해서 눈에 안 들어와요.
# 생성 완료 888/1000: 최근에 알게 된 디얼달링의 화장품은 디자인이 너무 독특해서 친구들 사이에서 인기예요.
# 생성 완료 889/1000: 최근에 구매한 테슬라의 액세서리는 정말 비싸다고 느껴진다.
# 생성 완료 890/1000: 드디어 테라모니터의 신제품을 구입했는데, 패키지에서부터 다양한 옵션을 선택할 수 있어 너무 만족스러워요!
# 생성 완료 891/1000: 최근에 구매한 엑소디아 스니커즈는 디자인은 멋진데, 가격이 너무 비싸서 아쉬웠어요.
# 생성 완료 892/1000: 쿠토모라는 브랜드의 가격은 저렴한 편에 속하지만, 인지도가 낮아서 아쉬워요.
# 생성 완료 893/1000: 비록 가격은 조금 높지만, 퀘스천마크의 패키지 디자인은 정말 매력적이어서 눈길을 사로잡습니다.
# 생성 완료 894/1000: 최근에 구매한 몽드드 기저귀는 유명한 브랜드는 아니지만 사용이 편리해서 만족해요.
# 생성 완료 895/1000: 요즘 주변에서 워낙에 인기가 많다는 뉴트로지나 세럼, 디자인도 깔끔하고 가격도 나름 합리적이어서 구매해봤어요.
# 생성 완료 896/1000: 도브 비누의 다양한 향이 매장에 준비되어 있어서 선택의 폭이 넓더라고요.
# 생성 완료 897/1000: 쿠팡의 패키지는 다양한 옵션을 제공하지만, 가끔 불필요한 구성품도 포함된 것 같아요.
# 생성 완료 898/1000: 마이쉐프의 다양한 요리 패키지는 선택의 폭이 넓어 언제나 쉽게 메뉴를 고를 수 있어요.
# 생성 완료 899/1000: 올드스쿨의 제품은 디자인이 촌스럽고 인기 없는 것 같아요.
# 생성 완료 900/1000: 크라운의 스낵팩은 종류가 많아서 매번 새롭게 도전할 수 있어요.
# 생성 완료 901/1000: 디올의 화장품 패키지는 예전보다 디자인이 단조로워져서 조금 실망스럽네요.
# 생성 완료 902/1000: 최근에 구매한 제니퍼룸 전기포트는 디자인이 세련되어서 주방에 놓아두는 것만으로도 분위기가 확 살아요.
# 생성 완료 903/1000: 오랜만에 소니 제품을 구매했는데, 다양한 옵션을 제공해서 선택하기 좋았어요.
# 생성 완료 904/1000: "이너스파의 화장품 패키지는 종류가 다양해서 고르기가 오히려 어려울 정도네요."
# 생성 완료 905/1000: 지난번에 구입한 바이레도 향수의 패키지는 정말 감각적이고 세련됐어요.
# 생성 완료 906/1000: 스와로브스키의 주얼리 박스는 디자인이 고급스럽고, 선물로 주기에도 너무 좋네요.
# 생성 완료 907/1000: 크리스찬디올의 향수는 디자인이 정말 우아해서 선물하기 좋지만, 가격대가 높아서 가끔 부담스러워요.
# 생성 완료 908/1000: "플라스틱 사용을 줄이기 위해 이케아가 다양한 친환경 포장재를 도입했는데, 디자인도 세련되고 가격도 합리적이라 인기가 많아요."
# 생성 완료 909/1000: 마리끌레르 화장품은 디자인이 너무 독특해서 주목 받기 좋아요.
# 생성 완료 910/1000: 최근에 구입한 세바메드 화장품 세트가 포장도 깔끔하고 사용하기 너무 편리하네요.
# 생성 완료 911/1000: 에코백에 담아주니 이동하기 편리하고, #바오바오의 다양한 디자인이 너무 마음에 들어요.
# 생성 완료 912/1000: 오랫동안 인기있었던 #토니모리의 립스틱은 디자인이 예쁘긴 한데, 가격이 조금 부담스럽네요.
# 생성 완료 913/1000: 다이소의 다양한 옵션으로 구성된 선물 패키지는 선택의 폭이 넓어서 좋아요.
# 생성 완료 914/1000: 최근 구매한 샤넬의 패키지는 정말 다양해서 선물하기도 좋고, 사용하기에도 너무 재밌어요.
# 생성 완료 915/1000: "소니의 헤드폰 케이스는 디자인이 깔끔하고 실용적이에요, 하지만 가격이 좀 비싸요."
# 생성 완료 916/1000: 레볼루션의 신제품 스킨케어 세트는 다양한 옵션을 제공하지만, 가격대가 조금 부담스럽네요.
# 생성 완료 917/1000: "아디다스의 운동화는 디자인은 훌륭하지만 가격이 비싸서 고민됩니다."
# 생성 완료 918/1000: 최근에 구입한 '아트박스'의 다이어리, 디자인이 너무 세련돼서 매일 들고 다니고 싶어요!
# 생성 완료 919/1000: "요즘 디지털 노마드들이 선호하는 #모노포드스튜디오 제품은 가격 대비 성능이 뛰어난데, 다양한 패키지 옵션이 있어서 선택의 폭이 넓어요."
# 생성 완료 920/1000: "한솔제지의 패키지는 디자인이 독특해서 선물용으로도 좋지만 가격이 좀 비싼 편이에요."
# 생성 완료 921/1000: "라코스테는 브랜드 인지도는 높은데, 가격은 좀 비싼 편이라 부담스러워요."
# 생성 완료 922/1000: #키르시의 다양한 패키지 옵션 덕분에 취향에 맞게 고를 수 있어서 좋았어요.
# 생성 완료 923/1000: 최근에 구입한 아웃도어 브랜드 '네파'의 다양한 옵션은 정말 실망스러웠어요.
# 생성 완료 924/1000: 리즈케어의 다양한 헤어팩은 가격대비 성능이 뛰어나서 만족스러워요.
# 생성 완료 925/1000: 최근에 구매한 샤넬 화장품 패키지는 디자인이 정말 세련됐지만, 가격이 부담스러워요.
# 생성 완료 926/1000: 이케아의 다양한 가구 제품들은 디자인이 독특해서 홈 인테리어에 적합하지만, 가격이 비싸게 느껴질 수 있어요.
# 생성 완료 927/1000: 브링그린의 스킨케어 제품은 가격은 저렴하지 않지만, 고급스러운 패키지 디자인이 마음에 드네요.
# 생성 완료 928/1000: 최근에 길리안의 초콜릿 패키지를 구매했는데, 외관은 꽤 고급스러웠지만 가격이 너무 비싸서 조금 실망했어요.
# 생성 완료 929/1000: 예쁘게 디자인된 이케아의 패키지는 집안 어디에 놔둬도 잘 어울려요.
# 생성 완료 930/1000: 포장 디자인이 너무 세련된 것 같아, 몬스터박스의 패키지가 눈에 띄네.
# 생성 완료 931/1000: 최근에 구입한 `레코르` 휴대용 텀블러는 디자인이 너무 예쁘고, 색상도 다양해서 하나만 고르기 힘들었어요.
# 생성 완료 932/1000: 다이소의 다양한 문구류는 항상 인기가 많아서 친구 선물로도 좋더라고요.
# 생성 완료 933/1000: 한성컴퓨터의 모니터 패키지는 너무 단조롭고 종류도 다양하지 않아요.
# 생성 완료 934/1000: 최근에 구매한 리바이스 청바지의 디자인은 세련되었지만, 가격이 우리가 생각했던 것보다 꽤 비쌌어요.
# 생성 완료 935/1000: 최근에 구매한 록시땅의 핸드크림 패키지가 정말 다양한 옵션이 있어서 선물하기 좋았어요.
# 생성 완료 936/1000: 아르마니의 향수는 유명하지만 최근 가격이 너무 올라서 부담스럽네요.
# 생성 완료 937/1000: 최근에 구매한 샤넬 향수의 패키지가 너무 고급져서 보는 것만으로도 기분이 좋아요.
# 생성 완료 938/1000: 조말론의 향수 패키지는 고급스러우면서도 다양한 옵션이 있어서 선물용으로도 좋아요.
# 생성 완료 939/1000: 마이쉘리프의 패키지는 다양한 색상과 디자인으로 선택의 폭이 넓어 정말 마음에 듭니다.
# 생성 완료 940/1000: 나이키는 다양한 스타일의 운동화를 제공하지만 가격은 조금 부담스러워요.
# 생성 완료 941/1000: 레드페이스의 아웃도어 용품은 디자인이 세련되어서 캠핑 가는 친구들이 자주 언급하더라고요.
# 생성 완료 942/1000: 포르쉐는 가격이 좀 높지만 그만큼 인지도가 높아서 사람들이 많이 찾는 것 같아요.
# 생성 완료 943/1000: 최근에 알게 된 리버풀의 가방은 디자인이 뛰어난 건 아닌데 여러 옵션이 있어서 고르기 좋았어요.
# 생성 완료 944/1000: 최근에 구매한 요거트메이커는 다이소 제품인데 가격대비 퀄리티가 놀랍네요.
# 생성 완료 945/1000: 최근에 사용해본 '리줌' 마우스는 디자인이 특별히 인상적이진 않았어요.
# 생성 완료 946/1000: 최근에 구매한 메리네일의 네일 스티커는 가격대가 적당하고 디자인도 세련돼서 아주 만족스럽습니다.
# API 호출 실패 947/1000: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-ChVBjJKjnJsnC8qgpuXZ8slT on tokens per min (TPM): Limit 30000, Used 29220, Requested 1430. Please try again in 1.3s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# 생성 완료 948/1000: 최근에 알게 된 '레브론'의 메이크업 브러쉬 세트는 가격 대비 품질이 아쉬워요.
# 생성 완료 949/1000: 써모스 보온병은 디자인도 세련돼서 사람들 눈길을 끌더라구요.
# 생성 완료 950/1000: 토니모리의 다양한 스킨케어 제품은 종류가 많아서 선택의 폭이 넓습니다만, 살짝 비싼 감이 있어요.
# 생성 완료 951/1000: 최근에 출시된 나이스웨이브 가방은 디자인은 예쁘지만, 브랜드 자체의 인지도가 높지 않아 고민 중입니다.
# 생성 완료 952/1000: 요즘 한샘 가구의 인지도가 많이 높아졌다고 느껴지네요. 주변에서도 많이들 쓰는 것 같아요.
# 생성 완료 953/1000: 노트북 가방은 역시 샤오미 제품이 다양한 옵션을 제공해서 선택의 폭이 넓어요.
# 생성 완료 954/1000: 최근에 구입한 #제로리빙 의 침대 프레임은 디자인이 너무 세련돼서 방 분위기가 확 좋아졌어요.
# 생성 완료 955/1000: 요즘 예쁜 디자인으로 인기를 끌고 있는 '모리나가 제과'의 패키지는 깔끔하고 세련되어 정말 마음에 들어요!
# 생성 완료 956/1000: 다양한 색상과 디자인으로 유명한 티르리르 귀걸이는 가격도 저렴해서 학생들도 부담 없이 구매할 수 있어 좋습니다.
# 생성 완료 957/1000: 최근에 사용해본 #포니이펙트의 립스틱, 가격도 적당하고 디자인이 너무 예뻐서 화장대에 두면 보기만 해도 기분이 좋아져요.
# 생성 완료 958/1000: 아디다스의 새로운 운동화는 디자인이 정말 세련되었지만 가격대가 조금 높게 느껴지네요.
# 생성 완료 959/1000: 요즘 핫한 브랜드인 #앳킨슨의 향수 패키지는 정말 세련되었지만, 가격은 다소 높은 편입니다.
# 생성 완료 960/1000: 친구가 추천해준 에이블씨엔씨의 화장품은 디자인이 참 평범하네요.
# 생성 완료 961/1000: 이번에 구매한 프롬비의 스마트 메모 패드는 디자인이 심플해서 업무용으로 제격입니다.
# 생성 완료 962/1000: 캐스키드슨의 패턴은 정말 다양해서 선택할 때마다 기분이 좋아져요.
# 생성 완료 963/1000: 아르마니 향수는 가격이 좀 비싸지만 패키지가 너무 고급스러워서 선물용으로 항상 선택하게 돼요.
# 생성 완료 964/1000: 화장품 브랜드 잇츠스킨의 패키지는 다양해서 선택하는 재미가 있더라고요.
# 생성 완료 965/1000: IHERB에서 구매한 NOW Foods의 다양한 비타민이 선택의 폭이 넓어 좋았어요.
# 생성 완료 966/1000: 텀프로젝트의 무선 이어폰 패키지는 다양한 색상 옵션이 있어 선택의 폭이 넓어 좋았어요.
# 생성 완료 967/1000: 요즘 자주 보이는 오르비스의 화장품, 가격은 좀 있지만 인지도가 높아서 써보고 싶네요.
# 생성 완료 968/1000: 히말라야 화장품은 가격 대비 품질이 좋아서 가성비가 뛰어나다는 평이 많아요.
# 생성 완료 969/1000: 친구에게 선물 받은 마시모두띠의 손수건, 디자인이 깔끔해서 매일 들고 다녀요.
# 생성 완료 970/1000: 노키아 제품의 디자인은 평범해서 특별히 눈에 띄지는 않네요.
# 생성 완료 971/1000: 애플의 가격은 여전히 고가지만, 브랜드 인지도나 디자인은 역시 기대를 저버리지 않네요.
# 생성 완료 972/1000: 이번에 도토리 컴퍼니의 가죽 지갑을 샀는데, 디자인이 정말 세련되고 고급스럽네요.
# 생성 완료 973/1000: 최근에 출시된 파펨의 새로운 향수 컬렉션은 다양한 향을 선택할 수 있어 만족스러웠어요.
# 생성 완료 974/1000: 한스킨의 다양한 마스크팩은 가성비가 좋고 피부 타입에 맞춰 선택할 수 있는 옵션이 많아 정말 마음에 들어요.
# 생성 완료 975/1000: 고센코리아의 다양한 테니스 라켓이 선택의 폭을 넓혀 줘서 경기 전 항상 기대감이 생깁니다.
# 생성 완료 976/1000: 최근에 구입한 '문장크래프트'의 패키지 디자인은 참 독특한 매력을 가지고 있어요. 특히나 다양한 색상 옵션도 있어서 고르는 재미가 쏠쏠하더라고요.
# 생성 완료 977/1000: 로디스의 가방은 디자인이 세련되어 눈에 확 띄지만 가격대가 좀 부담스럽네요.
# 생성 완료 978/1000: 요즘 베이지크의 세련된 디자인은 물론, 다양한 색상 옵션이 많아서 고르기 힘들 정도예요.
# 생성 완료 979/1000: 노트북을 구매할 때 맥북의 디자인적 매력은 누구도 무시할 수 없죠.
# 생성 완료 980/1000: 한국에서는 여전히 뱅앤올룹슨의 인지도가 낮아서 아쉬운 것 같아요.
# 생성 완료 981/1000: "아디다스의 다양한 스포츠웨어는 여전히 인기가 많지만, 가격대가 높아서 쉽게 구매하기 어렵네요."
# 생성 완료 982/1000: 오랜만에 산 #에이수스 보드, 가격은 저렴하진 않지만 성능은 확실히 믿음이 가네요.
# 생성 완료 983/1000: 최근 구입한 마이크로닉스의 게이밍 키보드는 디자인은 예쁘지만 가격이 너무 비싸서 아쉬웠어요.
# 생성 완료 984/1000: 요즘 다이소에서 파는 미니멀한 디자인의 플라스틱 보관함이 인기가 많더라고요.
# 생성 완료 985/1000: 최근에 알게 된 호호베베 기저귀는 패키지가 조금 독특해서 눈에 띄는데, 사용해보니 생각보다 편리해서 놀랐어요.
# 생성 완료 986/1000: 고급스러운 디자인의 '네이처리퍼블릭' 포장재가 마음에 드는데 가격이 좀 비싼 편이에요.
# 생성 완료 987/1000: 최근에 구매한 마스티프의 충전 케이스가 다양한 색상으로 나와서 고르는 재미가 있었어요!
# 생성 완료 988/1000: 테팔 커피메이커는 유명하지 않지만, 가격 대비 성능이 괜찮아서 만족스러워요.
# 생성 완료 989/1000: 나스의 립스틱은 가격대가 조금 높지만 다양한 색상 덕분에 선택의 폭이 넓어요.
# 생성 완료 990/1000: 아소스 브랜드의 의류는 디자인이 정말 세련됐지만, 가격이 상대적으로 높아서 망설여지네요.
# 생성 완료 991/1000: 최근 구입한 로모스 보조배터리의 디자인은 정말 깔끔하고 세련되어서 마음에 들었어요.
# 생성 완료 992/1000: 최근에 구매한 키노토 제품은 디자인이 참 세련됐어요. 특히 케이스가 너무 고급져 보이네요.
# 생성 완료 993/1000: 세계적으로 유명한 다이슨은 다양한 청소기 모델을 제공하지만, 일부는 가격이 비싸다는 느낌이 드네요.
# 생성 완료 994/1000: 요즘 B&O 헤드폰의 디자인이 예쁘긴 한데, 가격대가 좀 부담스럽네요.
# 생성 완료 995/1000: 리안체어가 디자인은 좋은데 가격이 너무 비싸서 망설여지네요.
# 생성 완료 996/1000: 최근에 구입한 마모트의 등산 가방은 다양한 색상 옵션이 있어서 정말 만족스럽습니다.
# 생성 완료 997/1000: 최근에 구매한 노르딕네스트의 주방용품 세트는 여전히 비싼 가격이라 아쉽네요.
# 생성 완료 998/1000: 아소스의 신상 가방은 색상이 예쁜데 가격이 조금 높은 것 같아요.
# 생성 완료 999/1000: "스위스 밀리터리의 다양한 여행가방 옵션은 어느 상황에서도 멋지게 어울려요."
# 생성 완료 1000/1000: 에스쁘아의 패키지는 다양한 색상과 디자인으로 사용자의 취향을 저격하여 좋았어요.
#
# === 생성된 데이터 예시 (5개) ===
#
# 1. 문장: 최근에 구입한 트라움 폼 매트리스, 디자인도 깔끔하고 다양한 옵션 선택이 가능해서 맘에 들어요.
#    엔티티:
#      ["브랜드#디자인", ['트라움 폼 매트리스', 8, 18], "positive"]
#      ["브랜드#다양성", ['다양한 옵션', 28, 34], "positive"]
#
# 2. 문장: 라미 만년필의 포장은 정말 고급스러워서 선물용으로도 손색없어요.
#    엔티티:
#      ["패키지/구성품#디자인", ['포장', 6, 8], "positive"]
#      ["브랜드#디자인", ['라미', 0, 2], "positive"]
#
# 3. 문장: 최근에 구매한 리바이스 청바지의 디자인이 정말 독특하고 멋스러워요. 게다가 여러 종류의 스타일이 있어서 선택의 폭이 넓어요.
#    엔티티:
#      ["브랜드#디자인", ['리바이스', 9, 12], "positive"]
#      ["브랜드#다양성", ['리바이스', 9, 12], "positive"]
#
# 4. 문장: 나이키 브랜드의 다양한 운동화 옵션이 너무 많아서 선택이 힘들었어요.
#    엔티티:
#      ["브랜드#다양성", ['나이키', 0, 3], "neutral"]
#
# 5. 문장: 이케아의 다양한 가구 옵션은 정말 매력적이지만, 품절이 잦아서 아쉬워요.
#    엔티티:
#      ["브랜드#다양성", ['이케아', 0, 3], "positive"]
# 엔티티 데이터가 direct_entity_ner_data2000_3.json에 저장되었습니다.
#
# === 생성 완료 ===
# direct_entity_ner_data2000_3.json - 직접 엔티티 형식 데이터
#
# === 원하는 형식 예시 ===
# 문장: 최근에 구입한 트라움 폼 매트리스, 디자인도 깔끔하고 다양한 옵션 선택이 가능해서 맘에 들어요.
# ['브랜드#디자인', ['트라움 폼 매트리스', 8, 18], 'positive']
# ['브랜드#다양성', ['다양한 옵션', 28, 34], 'positive']

# %%
import pandas as pd
augmented_df = pd.read_json("direct_entity_ner_data2000_3.json")

# %%
def contains_none(x):
    # 리스트 안에 None 또는 "None"이 있는지 재귀적으로 확인
    if isinstance(x, list):
        return any(contains_none(i) for i in x)
    return x is None or x == "None"

# 필터링
augmented_df = augmented_df[~augmented_df['entities'].apply(contains_none)]

# %%
augmented_df['id'] = augmented_df.index
augmented_df = augmented_df.rename(columns={'sentence':'sentence_form', 'entities' : 'annotation'})
# Out:
# C:\Users\leopp\AppData\Local\Temp\ipykernel_15024\1245537395.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   augmented_df['id'] = augmented_df.index

# %%
original_df = pd.read_csv("augmented_train_expanded_2.csv", index_col=0)

# %%
augmented = pd.concat([original_df, augmented_df], axis = 0)

# %%
augmented.to_csv("augmented_train_expanded_3.csv")

# %%
import pandas as pd
df = pd.read_csv("augmented_train_expanded_3.csv", index_col=0)
df
# Out:
#                               id  \
# 0    nikluge-sa-2022-train-00001
# 1    nikluge-sa-2022-train-00002
# 2    nikluge-sa-2022-train-00003
# 3    nikluge-sa-2022-train-00004
# 4    nikluge-sa-2022-train-00005
# ..                           ...
# 993                          993
# 994                          994
# 995                          995
# 996                          996
# 997                          997
#
#                                          sentence_form  \
# 0               둘쨋날은 미친듯이 밟아봤더니 기어가 헛돌면서 틱틱 소리가 나서 경악.
# 1    이거 뭐 삐꾸를 준 거 아냐 불안하고, 거금 투자한 게 왜 이래.. 싶어서 정이 확...
# 2                 간사하게도 그 이후에는 라이딩이 아주 즐거워져서 만족스럽게 탔다.
# 3    샥이 없는 모델이라 일반 도로에서 타면 노면의 진동 때문에 손목이 덜덜덜 떨리고 이...
# 4                       안장도 딱딱해서 엉덩이가 아팠는데 무시하고 타고 있다.
# ..                                                 ...
# 993     최근에 구입한 마모트의 등산 가방은 다양한 색상 옵션이 있어서 정말 만족스럽습니다.
# 994         최근에 구매한 노르딕네스트의 주방용품 세트는 여전히 비싼 가격이라 아쉽네요.
# 995               아소스의 신상 가방은 색상이 예쁜데 가격이 조금 높은 것 같아요.
# 996        "스위스 밀리터리의 다양한 여행가방 옵션은 어느 상황에서도 멋지게 어울려요."
# 997       에스쁘아의 패키지는 다양한 색상과 디자인으로 사용자의 취향을 저격하여 좋았어요.
#
#                                             annotation
# 0              [['본품#품질', ['기어', 16, 18], 'negative']]
# 1           [['본품#품질', ['기어 텐션', 67, 72], 'negative']]
# 2             [['제품 전체#일반', [None, 0, 0], 'positive']]
# 3        [['제품 전체#일반', ['샥이 없는 모델', 0, 8], 'neutral']]
# 4                [['본품#일반', ['안장', 0, 2], 'negative']]
# ..                                                 ...
# 993         [['브랜드#다양성', ['마모트', 11, 14], 'positive']]
# 994        [['브랜드#가격', ['노르딕네스트', 8, 14], 'negative']]
# 995  [['브랜드#디자인', ['아소스', 0, 3], 'positive'], ['브랜드...
# 996      [['브랜드#다양성', ['스위스 밀리터리', 0, 8], 'positive']]
# 997  [['브랜드#디자인', ['에스쁘아', 0, 4], 'positive'], ['패키...
#
# [4873 rows x 3 columns]

# %%
def contains_none_in_len1_lists(x):
    if isinstance(x, list):
        # 현재 리스트가 길이 1이고 그 안에 None/"None"이 있는 경우
        if len(x) == 1:
            val = x[0]
            if not isinstance(val, list):
                return val is None or val == "None"
            else:
                return val[1][0] is None or val[1][0] == "None"
        else:
            # 길이가 2 이상이면 내부 요소들을 재귀적으로 검사
            return False
    else:
        # 리스트가 아니면 False (탐색 종료)
        return False

import ast
df.annotation = df.annotation.apply(ast.literal_eval)
df_none = df[df['annotation'].apply(contains_none_in_len1_lists)]
df = df[~df['annotation'].apply(contains_none_in_len1_lists)]

# %%
sampled_df = df_none.sample(frac=0.1, random_state=42)
n_df = pd.concat([df, sampled_df], axis=0).reset_index(drop=True)

# %%
n_df.to_csv("augmented_train_expanded_3(nullX_10%).csv")

# %%
df.to_csv("augmented_train_expanded_3.csv")
